# %% [markdown]
# # **Tarea 5**
#
# # Script en R - Plot
#
# #### 1. Replicar el siguiente gráfico

# %%
import pandas as pd
import os # directorio (carpeta de trabajo)
os.getcwd()

# Primero, establecemos nuestro directorio para llamar a los archivos
cultivation = pd.read_excel("../../data/produccion_coca/6.1.1_-_Illicit_coca_bush_cultivation.xlsx", skiprows=2)
# Leemos el archivo y omitimos las filas que no necesitamos
cultivation = cultivation.drop(cultivation.index[5:11])
cultivation = cultivation.reset_index(drop=True)
cultivation = cultivation.drop(cultivation.index[0])
cultivation = cultivation.reset_index(drop=True)

# %%
# Renombramos la primera columna como Country
cultivation = cultivation.rename(columns={"Unnamed: 0": "Country"})

# Renombramos las columnas de los años
cultivation.columns.values[1:6] = ["2009", "2010", "2011", "2012", "2013"]

# Renombramos las filas para que los nombres de los países coincidan con el ejemplo
cultivation.loc[0:3, "Country"] = ["Bolivia", "Colombia", "Peru", "Total"]
cultivation = cultivation.reset_index(drop=True)

# %%
cultivation
# Out:
#     Country      2009      2010      2011      2012      2013      2014  \
# 0   Bolivia   30900.0   31000.0   27200.0   25300.0   23000.0   20400.0
# 1  Colombia   73000.0   62000.0   64000.0   48000.0   48000.0   69000.0
# 2      Peru   59900.0   61200.0   62500.0   60400.0   49800.0   42900.0
# 3     Total  163800.0  154200.0  153700.0  133700.0  120800.0  132300.0
#
#        2015      2016      2017      2018      2019      2020
# 0   20200.0   23100.0   24500.0   23100.0   25500.0   29400.0
# 1   96000.0  146000.0  171000.0  169000.0  154000.0  142800.0
# 2   40300.0   43900.0   49900.0   54100.0   54700.0   61800.0
# 3  156500.0  213000.0  245400.0  246200.0  234200.0  234200.0

# %%
import matplotlib.pyplot as plt

# Ahora, con la base ya limpia podemos crear el gráfico
# Seleccionamos los datos que necesitamos de la base
grafico1 = cultivation.iloc[0:3, 1:13]
colores = ["red", "green", "gray"]  # Colores del ejemplo

# Colocamos los datos y el formato
plt.figure(figsize=(10, 6))
plt.plot(range(2009, 2021), grafico1.iloc[0], color=colores[0], linewidth=2, label="Bolivia")
plt.plot(range(2009, 2021), grafico1.iloc[1], color=colores[1], linewidth=2, label="Colombia")
plt.plot(range(2009, 2021), grafico1.iloc[2], color=colores[2], linewidth=2, label="Peru")
plt.scatter(range(2009, 2021), grafico1.iloc[0], color=colores[0], marker='o')
plt.scatter(range(2009, 2021), grafico1.iloc[1], color=colores[1], marker='o')
plt.scatter(range(2009, 2021), grafico1.iloc[2], color=colores[2], marker='o')
plt.xlabel("Años")
plt.ylabel("Producción de hoja de coca por hectáreas")
plt.title("Figura 1: Producción de hoja de coca en hectáreas")
plt.ylim(0, grafico1.max().max())

# Ponemos la leyenda
plt.legend(loc="upper right")
# Agregamos el pie de página
plt.figtext(0.5, 0.02, "Nota: Este gráfico muestra la producción de hoja de coca por años en la región andina usando datos de UNODC.",
            ha="center", fontsize=9)
# Observamos el gráfico
plt.show()

# %% [markdown]
# #### 2. Replicar el gráfico con los datos de erradicación de hectáreas de hoja de coca

# %%
# Cargamos el archivo
eradication = pd.read_excel("../../data/produccion_coca/6.1.2_-_Eradication_of_coca_bush.xlsx")
eradication.columns = eradication.iloc[0].values
eradication = eradication[1:].reset_index(drop=True)
eradication = eradication.drop(eradication.index[3:16]).reset_index(drop=True)
eradication = eradication.drop(columns=[eradication.columns[0], eradication.columns[1], eradication.columns[17]])
eradication   #la dara necesita limpieza
# Out:
#                                 NaN Method of eradication     Unit     2009.0  \
# 0  Bolivia (Plurinational State of)                manual  hectare    6341.00
# 1                          Colombia                manual  hectare  165336.95
# 2                              Peru                manual  hectare   10025.00
#
#       2010.0     2011.0     2012.0     2013.0      2014.0     2015.0   2016.0  \
# 0    8200.00   10509.00   11044.00  11407.000  11144.0000  11020.000   6577.0
# 1  145743.69  138503.23  131004.75  69173.469  67234.5178  49967.463  17642.0
# 2   12033.00   10290.00   14171.00  23785.000  31206.0000  35868.000  30151.0
#
#      2017.0    2018.0    2019.0     2020.0
# 0   7237.00  11174.00   9205.00    2177.00
# 1  52000.67  59977.95  94606.00  130147.33
# 2  25784.00  25106.67  25526.31    6272.80

# %%
# Renombramos la primera columna como en el caso anterior
eradication = eradication.rename(columns={eradication.columns[0]: "Country"})
eradication.columns.values[3:15] = eradication.columns.values[3:15].astype(int).astype(str)

#Cambiamos los nombres para que coincidan
eradication.loc[0:2, "Country"] = ["Bolivia", "Colombia", "Peru"]
eradication = eradication.reset_index(drop=True)
eradication
# Out:
#     Country Method of eradication     Unit       2009       2010       2011  \
# 0   Bolivia                manual  hectare    6341.00    8200.00   10509.00
# 1  Colombia                manual  hectare  165336.95  145743.69  138503.23
# 2      Peru                manual  hectare   10025.00   12033.00   10290.00
#
#         2012       2013        2014       2015     2016      2017      2018  \
# 0   11044.00  11407.000  11144.0000  11020.000   6577.0   7237.00  11174.00
# 1  131004.75  69173.469  67234.5178  49967.463  17642.0  52000.67  59977.95
# 2   14171.00  23785.000  31206.0000  35868.000  30151.0  25784.00  25106.67
#
#        2019       2020
# 0   9205.00    2177.00
# 1  94606.00  130147.33
# 2  25526.31    6272.80

# %%
# Ahora podemos crear el gráfico

grafico2 = eradication.iloc[0:3, 3:15]

colores2 = ["red", "green", "gray"]
plt.plot(range(2009, 2021), grafico2.iloc[0, :], linestyle='none', marker='o', color='white')
plt.xlim(2009, 2020)
plt.ylim(0, grafico2.max().max())
plt.xlabel("Años")
plt.ylabel("Erradicación de la producción de coca por hectárea")
plt.title("Figura 2: Erradicación de la producción de hoja de coca por hectárea, 2009-2020")

for i in range(3):
    plt.plot(range(2009, 2021), grafico2.iloc[i, :], color=colores2[i], linewidth=2)
    plt.scatter(range(2009, 2021), grafico2.iloc[i, :], color=colores2[i], marker='o')

plt.legend(["Bolivia", "Colombia", "Peru"], loc="upper right")
plt.text(0.5, -0.1, "Nota: Este gráfico muestra la erradicación de la producción de hoja de coca por años en la región andina usando UNODC data.", transform=plt.gca().transAxes, fontsize=10, verticalalignment='bottom')
# Observamos el gráfico
plt.show()

# %% [markdown]
# #### 3. Replicar el gráfico con la producción y erradicación de hoja de coca en el Perú.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filtramos los datos para Perú en la base de cultivation
cultivation_peru = cultivation[cultivation["Country"] == "Peru"].iloc[:, 1:13]

# Filtramos los datos para Perú en la base de eradication
eradication_peru = eradication[eradication["Country"] == "Peru"].iloc[:, 3:15]

# Damos formato a los datos para trabajarlos
cultivation_peru_long = cultivation_peru.melt(var_name="Año", value_name="Producción")
eradication_peru_long = eradication_peru.melt(var_name="Año", value_name="Erradicación")

# Convertimos la columna "Año" a enteros. Sin este paso, los años salen en desorden
cultivation_peru_long["Año"] = pd.to_numeric(cultivation_peru_long["Año"], errors="coerce")
eradication_peru_long["Año"] = pd.to_numeric(eradication_peru_long["Año"], errors="coerce")

# Eliminar filas con valores NaN en la columna "Año" porque alteran el gráfico
cultivation_peru_long = cultivation_peru_long.dropna(subset=["Año"])
eradication_peru_long = eradication_peru_long.dropna(subset=["Año"])

# Ordenamos los datos por año debido al problema anterior
cultivation_peru_long = cultivation_peru_long.sort_values("Año")
eradication_peru_long = eradication_peru_long.sort_values("Año")

# Ahora sí podemos crear el gráfico para Perú
plt.plot(cultivation_peru_long["Año"], cultivation_peru_long["Producción"], color="red", linestyle="solid", linewidth=1.5)
plt.scatter(cultivation_peru_long["Año"], cultivation_peru_long["Producción"], color="red", s=30)
plt.plot(eradication_peru_long["Año"], eradication_peru_long["Erradicación"], color="green", linestyle="solid", linewidth=1.5)
plt.scatter(eradication_peru_long["Año"], eradication_peru_long["Erradicación"], color="green", s=30)
# Añadimos el texto
plt.xlabel("Años")
plt.ylabel("Producción / Erradicación de hoja de coca por hectáreas")
plt.title("Producción y Erradicación de la hoja de coca en Perú, 2009-2020")
plt.xticks(rotation=45)
plt.legend(["Producción", "Erradicación"])
plt.grid(True)

plt.show()

# %% [markdown]
# # Script en R - REGEX
#
# #### 1. Convertimos coordenadas en la base de datos metropolitano

# %%
# establecemos directorio
import os # directorio (carpeta de trabajo)
os.getcwd()
# Out:
# 'C:\\Users\\Sistema\\Documents\\GitHub\\1ECO35_2023_1\\Labs\\tarea5'

# %%
#abrimos nuestra base de datos
import pandas as pd

base1 = pd.read_excel("../../data/metropolitano.xlsx") # Subir base de datos
base1
# Out:
#       id  id_transport  cod_district       district transport_type  \
# 0      1             1      150112.0  independencia  metropolitano
# 1      2             1      150112.0  independencia  metropolitano
# 2      3             1      150112.0  independencia  metropolitano
# 3      4             1      150112.0  independencia  metropolitano
# 4      5             1      150112.0  independencia  metropolitano
# ..   ...           ...           ...            ...            ...
# 135  154             1           NaN            NaN  alimentador_8
# 136  155             1           NaN            NaN  alimentador_8
# 137  156             1           NaN            NaN  alimentador_8
# 138  157             1           NaN            NaN  alimentador_8
# 139  158             1           NaN            NaN  alimentador_8
#
#          station_name     sur_latitud  oeste_longitud
# 0         E. NARANJAL   11°58'51.19"S   77° 3'31.63"O
# 1           IZAGUIRRE   11°59'22.96"S   77° 3'25.30"O
# 2         PACIFICO E1   11°59'41.19"S   77° 3'21.84"O
# 3    INDEPENDENCIA E1   11°59'55.00"S   77° 3'18.79"O
# 4         JAZMINES E1    12° 0'7.88"S   77° 3'17.16"O
# ..                ...             ...             ...
# 135             ABTAO   12° 3'28.98"S   77° 1'20.22"O
# 136       ANDAHUAYLAS   12° 3'30.81"S   77° 1'34.43"O
# 137           ABANCAY   12° 3'32.80"S   77° 1'49.73"O
# 138  ESTACIÓN CENTRAL   12° 3'30.64"S   77° 2'11.10"O
# 139           HUANUCO   12° 3'27.47"S    77° 1'4.61"O
#
# [140 rows x 8 columns]

# %%
# creamos una copia que se llamará "data2"
data2 = base1.copy()

# %%
# creamos una función apropiada para convertir las coordenadas

import re
def convert_gps(x):
    signo = -1 if re.search('[swSWoO-]', x) else 1
    regex = re.compile(r'\s?(\d+)\s*°\s*(\d+)\'\s*(\d+(?:\.\d+)?)')
    match = regex.match(x)
    if match:
        grados = float(match.group(1))
        minutos = float(match.group(2))
        segundos = float(match.group(3))
        return signo * (grados + minutos / 60 + segundos / 3600)
    else:
        return None

# %%
#aplicamos a data2 para obtener la transformación de las coordenadas a "latitud" y "longitud"
data2['latitud'] = data2.sur_latitud.map(convert_gps)
data2['longitud'] = data2.oeste_longitud.map(convert_gps)

# %%
#chequeamos los resultados
data2
# Out:
#       id  id_transport  cod_district       district transport_type  \
# 0      1             1      150112.0  independencia  metropolitano
# 1      2             1      150112.0  independencia  metropolitano
# 2      3             1      150112.0  independencia  metropolitano
# 3      4             1      150112.0  independencia  metropolitano
# 4      5             1      150112.0  independencia  metropolitano
# ..   ...           ...           ...            ...            ...
# 135  154             1           NaN            NaN  alimentador_8
# 136  155             1           NaN            NaN  alimentador_8
# 137  156             1           NaN            NaN  alimentador_8
# 138  157             1           NaN            NaN  alimentador_8
# 139  158             1           NaN            NaN  alimentador_8
#
#          station_name     sur_latitud  oeste_longitud    latitud   longitud
# 0         E. NARANJAL   11°58'51.19"S   77° 3'31.63"O -11.980886 -77.058786
# 1           IZAGUIRRE   11°59'22.96"S   77° 3'25.30"O -11.989711 -77.057028
# 2         PACIFICO E1   11°59'41.19"S   77° 3'21.84"O -11.994775 -77.056067
# 3    INDEPENDENCIA E1   11°59'55.00"S   77° 3'18.79"O -11.998611 -77.055219
# 4         JAZMINES E1    12° 0'7.88"S   77° 3'17.16"O -12.002189 -77.054767
# ..                ...             ...             ...        ...        ...
# 135             ABTAO   12° 3'28.98"S   77° 1'20.22"O -12.058050 -77.022283
# 136       ANDAHUAYLAS   12° 3'30.81"S   77° 1'34.43"O -12.058558 -77.026231
# 137           ABANCAY   12° 3'32.80"S   77° 1'49.73"O -12.059111 -77.030481
# 138  ESTACIÓN CENTRAL   12° 3'30.64"S   77° 2'11.10"O -12.058511 -77.036417
# 139           HUANUCO   12° 3'27.47"S    77° 1'4.61"O -12.057631 -77.017947
#
# [140 rows x 10 columns]

# %% [markdown]
# #### 2. Base de estudiantes

# %%
import pandas as pd
import numpy as np
import re  # for regular expressions (REGEX)
import os  # for directorio
import unidecode # to drop tildes
from datetime import datetime  # library for time
import warnings
import math
warnings.filterwarnings('ignore')

# %%
# Establecemos nuestro directorio
os.getcwd()
# Out:
# 'C:\\Users\\Sistema\\Documents\\GitHub\\1ECO35_2023_1\\Labs\\tarea5'

# %%
# Cargamos la data y observamos que se encuentra muy sucia
data = pd.read_excel("../../data/estudiantes/base_students.xlsx") # Subir base de datos
data
# Out:
#                                     NAME          BORN_DATE             AGE  \
# 0             JOAN AYALA FERRERAS --- =9  23   /08/1998 "#%            !#10
# 1                     JOAN 3 BAEZ TEJADO       22/02/2004 !              15
# 2                  MARC BASTARDES SOTO -      05   /01/1998          ****14
# 3               JOSEP ANGUERA VILAFRANCA         21/02/1999              16
# 4                     JOAN ANDREU CRUZ /   27/06/1982 00:00              15
# 5            JORDI RAYA 73738 )= GAVILAN         15/06/1991              17
# 6      ********** ARAN ALVAREZ FERNÁNDEZ      03/09   /1993             !12
# 7                   JAVIER BENITEZ JOSE3         18/02/1975              11
# 8                   MARIO PASCUAL FLORES   14/11/1986 00:00               8
# 9                      JESUS AYALA TORNÉ         16/08/1993               9
# 10       GEMMA 234 >_ LISTAN FIGUERAS .0         16/07/1992           1   1
# 11                 SILVIA RASERO GAVILAN          100:00:00          1   3
# 12                ALBERT ARNALOT PUIG !2      18/03/2   001               6
# 13                 MARIA MOLINER GARRIDO         28/08/2000               7
# 14           BERTA GALOBART .--56 GARCIA         22/03/1973               6
# 15              BERTA LÓPEZ GARRIGASSAIT         19/05/1998               5
# 16                  MIREIA SÁNCHEZ GÓMEZ   28/11/1982 00:00               7
# 17                  GEMMA ALAVEDRA SUNYÉ      02/01#6)/1992            28..
# 18           MARIA ISABEL ALIGUÉ BONVEHÍ         13/01/2000              14
# 19                     TONI MAS FRANCH .         26/03/1995      16 --{{%/%
# 20                 ALEJANDRO ALOY COMPTE   05/01/1989 00:00              15
# 21               JOAN MARTÍ ASENSIO VEGA         08/03/2003              16
# 22               CARLOS ACUÑA TORT--{{++         03/07/1979              14
# 23  DAVID  -…............. ALGUÉ TRANCHO         18/10/1995          999999
# 24               CRISTINA BADIA CASTILLO     08/0    2/1990  dice tener 11
# 25     JULIO ALBERTO 6787 BENITEZ FLORES   26/09/1977 00:00              13
# 26               CRISTINA ARISSA HERMOSO         16/04/2000              20
# 27           JOSÉ ANTONIO BARALDÉS PARDO      05/05   /1982              14
# 28                  2JORDI SUAREZ GARZÓN         27/01/1999            && 7
# 29                 JUAN MANUEL GUTIERREZ         18/10/1995              15
# 30                       JOAQUIN GARCIA            00/00/00              14
# 31           DIANA .,,;; TORRES MARQUINA          1/10/2004           99999
# 32                   JOSEPH AGUILAR SOTO         18/12/1998              12
# 33                  PEDRO PALO DOMINGUEZ         18/10/1999              11
# 34              JOSÉ FELICIANO SATURNINO         18/06/2000              10
# 35       */-SEBASTIAN GUTIERREZ CASIMIRO   18/10/1996 -----              14
# 36                  ANDREA PALOMINO RIOS         18/05/1997              13
# 37                   CARLOS DAGA .. RIOS          4/10/2003               7
# 38                   JUAN MENDOZA GARCIA         18/10/2004               6
# 39               JORGE #$% 6TAZO TAZO --         31/05/1999              11
# 40            FRANCISCO GONZALES MELCHOR    1     8/10/2006               4
# 41              HUGO PACHECO 23 MANRIQUE         10/01/2003               7
# 42                    JUAN MANUEL VARGAS         18/10/2008              12
# 43                   KATY34 MATOS FLORES         18/04/2010              10
# 44    REYNA BALLON RIOS 9999999999999999                NaN            ----
# 45               BIANCA RIVAROLA RICARDO             000000              15
# 46                JAQUELINE GARCIA MATOS         18/10/2012               8
# 47                   FABIOLA MAGDA RIOS+        18/12/2 005              10
#
#    TYPE_ADM_SCHOOL       GENDER                       MAIL  \
# 0          publico    M    ALEE      albatros001@wandoo.es
# 1          privade          mal         albert@intercom.es
# 2          public0      malllle       alien_10@intercom.es
# 3           public       mal ee         amores@hotmail.com
# 4           public        m  al          anabel@altecom.es
# 5          publico      maleeee       antig56a@minorisa.es
# 6           public      malllle  ballador_rios@hotmail.com
# 7           public      malllle       balladora@altecom.es
# 8           privde    malll  le       barbilla@hotmail.com
# 9           prvade         male       besugo13@minorisa.es
# 10          public       female            bogart@terra.es
# 11           pblic       female              bond@terra.es
# 12          public         mmle      carretero@intercom.es
# 13         privade       female            cela@altecom.es
# 14         publico    femmallee           coco@hotmail.com
# 15     Public  ooo        femae       conejo11@minorisa.es
# 16         privade       female          corcel@altecom.es
# 17         privade        fmale         dorada@intercom.es
# 18         publicp      ffemale           elisa@altecom.es
# 19             NaN         male        encarna@hotmail.com
# 20         privade       maaale          entesa@altecom.es
# 21         miembro      maleeee        groucho@intercom.es
# 22          public      maleeee          harpo@hotmail.com
# 23          public      maleeee    hispa@cataloniamail.com
# 24          public      femmale          madonna@wandoo.es
# 25          public         male      mata_hari@intercom.es
# 26         privade      femmale        melanie@minorisa.es
# 27         public0         male     melquíades@hotmail.com
# 28          public         male    abogados_15@hotmail.com
# 29          public         male              bond@terra.es
# 30         private         male           garcia@gmail.com
# 31         privade         fele          diana@intercom.es
# 32  publicoooooooo         male   torresmarquina@gmail.com
# 33         public0         male     pdominguez@hotmail.com
# 34         privade          mle       satur_seb15@terra.es
# 35          public        ma le          mendoda@gmail.com
# 36        pu  blic        feale  palomino_rios@intercom.es
# 37          public         male          mendoda@gmail.com
# 38        publllic        ma le            jmg@hotmail.com
# 39         privado          mle            tazoj@gmail.com
# 40         privade         male    gon_melchor@hotmail.com
# 41         privade         male          mendoda@gmail.com
# 42          public        maloo            jmv@intercom.es
# 43         pribado          NaN          mflores@gmail.com
# 44         privade      fe m le       brios100@intercom.es
# 45          public        fmale          mendoda@gmail.com
# 46          public  f  emaleeee      jaqumatos@hotmail.com
# 47          public      fm  ale          fmagt@intercom.es
#
#                     DNI_NUMBER  \
# 0      dni padre: 04-156597865
# 1      dni padre: 02-156597865
# 2                 01-156597872
# 3       dni madre 01-156597872
# 4                 01-156597872
# 5      dni padre: 01-156597865
# 6       dni madre 01-156597872
# 7       dni madre 01-156597872
# 8       dni madre 01-156597872
# 9      dni padre: 02-156597865
# 10  dni apoderado 01-156597898
# 11                01-156597898
# 12      dni madre 01-156597872
# 13      dni madre 01-156597872
# 14      dni madre 01-156597872
# 15                01-156597872
# 16      dni madre 01-156597872
# 17      dni madre 01-156597872
# 18      dni madre 01-156597872
# 19      dni madre 01-156597872
# 20     dni padre: 01-156597865
# 21      dni madre 01-156597872
# 22  dni apoderado 01-156597898
# 23  dni apoderado 01-156597898
# 24  dni apoderado 01-156597898
# 25                01-156597898
# 26  dni apoderado 01-156597898
# 27  dni apoderado 01-156597898
# 28  dni apoderado 01-156597898
# 29      dni madre 01-156597872
# 30     dni padre: 03-156597865
# 31      dni madre 01-156597872
# 32     dni padre: 02-156597865
# 33  dni apoderado 01-156597898
# 34     dni padre: 02-156597865
# 35  dni apoderado 01-156597898
# 36     dni padre: 03-156597865
# 37  dni apoderado 01-156597898
# 38      dni madre 01-156597872
# 39         padre: 01-156597865
# 40  dni apoderado 01-156597898
# 41      dni madre 01-156597872
# 42     dni padre: 02-156597865
# 43     dni padre: 02-156597865
# 44     dni padre: 02-156597865
# 45      dni madre 01-156597872
# 46  dni apoderado 01-156597898
# 47                01-156597898
#
#                                         observaciones
# 0                nombre correcto es Roberto daga rios
# 1                                                 NaN
# 2                                  edad correta es 15
# 3                                                 NaN
# 4                                                 NaN
# 5   Beneficiado del programa Juntos, tiene 4 hermanos
# 6                                                 NaN
# 7              asiste a una II.EE de jornada completa
# 8                                                 NaN
# 9   nombre correcto es Jesus Mendieta Jimenez, asi...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13          nombre correcto es Fanny Cienfuegos prado
# 14                                                NaN
# 15   tiene 4 hemanos, asiste a una II.EE de jornad...
# 16                                                NaN
# 17                                   tiene 1 hermanas
# 18                                                NaN
# 19                                                NaN
# 20  Beneficiado del programa Juntos, nombre correc...
# 21                                                NaN
# 22                                                NaN
# 23   tiene 2 hermanos, Beneficiado del programa Ju...
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  Asiste a una II.EE de jornada completa, edad c...
# 28                                                NaN
# 29                    Beneficiado del programa Juntos
# 30                                                NaN
# 31                                                NaN
# 32  Beneficiado del programa Juntos, edad correta ...
# 33                                                NaN
# 34                    Beneficiado del programa Juntos
# 35                                                NaN
# 36                                                NaN
# 37            nombre correcto es Henry paulino flores
# 38                                                NaN
# 39                                 edad correta es 10
# 40                                                NaN
# 41                    Beneficiado del programa Juntos
# 42                                                NaN
# 43                                                NaN
# 44                    Beneficiado del programa Juntos
# 45                                                NaN
# 46                                                NaN
# 47   tiene 2 hermanas, asiste a una II.EE de jorna...

# %% [markdown]
# * Limpiar el nombre de los estudiantes

# %%
# Limpiamos los caracteres extraños de la variable NAME
data['NAME'] = data['NAME'].apply(lambda x: re.sub(r'[^a-zA-Z ]', '', x))

# %% [markdown]
# * Similarmente al item anterior, limpiar la fecha de nacimiento y edad y asignar el formato date

# %%
# Comenzamos limpiando BORN_DATE utilizando regex
data['BORN_DATE'] = data['BORN_DATE'].replace(r'[^0-9/]', '', regex=True)

# Tenemos que darle formato de datetime para que lo lea como fecha
data['BORN_DATE'] = data['BORN_DATE'].apply(lambda x: pd.to_datetime(x, format='%d/%m/%Y', errors='coerce'))

# Eliminamos filas con fechas inválidas
data = data.dropna(subset=['BORN_DATE'])

# %% [markdown]
# Creamos la variable año de nacimiento (YEAR_OF_BIRTH)

# %%
# Ahora limpiamos AGE con regex
data['AGE'] = data['AGE'].replace(r'\D', '', regex=True)

# Importante: convertirlo a numérico
data['AGE'] = pd.to_numeric(data['AGE'], errors='coerce')

#creamos la variable año de nacimiento
data['BORN_DATE'] = data['BORN_DATE'].astype(str)
data['YEAR_OF_BIRTH'] = data['BORN_DATE'].str.extract(r'(\d{4})')

# Convertimos la variable YEAR_OF_BIRTH a dato numérico
data['YEAR_OF_BIRTH'] = pd.to_numeric(data['YEAR_OF_BIRTH'], errors='coerce')

# %% [markdown]
# * Use la variable GENDER para crear una dummy que tome el valor de 1 para female y 0 para males.

# %%
# Limpiamos la variable GENDER y asignamos male si el dato contiene m y female si contiene f. Esto es importante para convertirlo en dummy después.
data['GENDER'] = data['GENDER'].str.lower()
data['GENDER'] = data['GENDER'].apply(lambda x: 'female' if re.search(r'f', str(x)) else ('male' if re.search(r'm', str(x)) else None))

# Eliminamos filas con valores nulos
data = data.dropna(subset=['GENDER'])

# Ahora convertimos a dummy, considerando que 1 es para female y 0 para male
data['GENDER'] = pd.get_dummies(data['GENDER'], drop_first=True)
data['GENDER'] = 1 - data['GENDER']

# %% [markdown]
# * Similarmente, crear una variable dummy que tome el valor de 1 si el colegio al cual asiste la o el menor es pública, y 0 si es privada.

# %%
# Ahora limpiamos la variable tipo de escuela. Igual que el caso anterior, le damos el valor de publico si contiene "pu" y privado si contiene "pr"
data.loc[data['TYPE_ADM_SCHOOL'].str.contains(r'pu', case=False, na=False), 'TYPE_ADM_SCHOOL'] = 'publico'
data.loc[data['TYPE_ADM_SCHOOL'].str.contains(r'pr', case=False, na=False), 'TYPE_ADM_SCHOOL'] = 'privado'

#Convertimos a dummy
data['TYPE_ADM_SCHOOL'] = data['TYPE_ADM_SCHOOL'].replace({'publico': 1, 'privado': 0})

# %% [markdown]
# * Creamos la variable USUARIO

# %%
# Creamos una nueva variable "USUARIO" usando datos del correo electrónico
data['USUARIO'] = data['MAIL'].str.extract(r'(\w+)@')

# %% [markdown]
# La pregunta pedía agregar los datos del profesor

# %%
# Agregamos la información del proesor en NAME, MAIL y USUARIO
nueva_fila = {'NAME': 'ROBERTO MENDOZA MATOS', 'MAIL': 'rmendozam@pucp.edu.pe', 'USUARIO': 'rmandozam'}

# Agregamos la nueva fila al DataFrame
data = data.append(nueva_fila, ignore_index=True)

# %% [markdown]
# Crear una variable con el número de DNI del padre, madre o apoderado.

# %%
# Para esto, limpiamos DNI_NUMBER considerando que deben mantenerse los números y eliminar los otros caracteres
data['DNI_NUMBER'] = data['DNI_NUMBER'].replace(r'\D', '', regex=True)

# %% [markdown]
# Con "observaciones"
#
# Recuperar el nombre y edad correctos, y reemplazarlo en las variables de nombre (NAME) y edad respectivamente (AGE).

# %%
# Recogemos los datos correctos respecto al nombre de observaciones 
regex = re.compile('(.+)(correcto es)|,(.*)')

# lo guardamos en nombre_correcto
data['nombre_correcto'] = np.where(data['observaciones'].astype(str).str.match(regex), data['observaciones'].astype(str).str.replace(regex, '').str.strip(), None)
data['nombre_correcto']

# Reemplazamos en NAME
data['NAME'] = data['nombre_correcto'].combine_first(data['NAME'])
data['NAME']

# Ahora eliminamos la columna nombre_correcto
data = data.drop(data.columns[10], axis=1)

# %% [markdown]
# Crear una variable con la cantidad de hermana/os del estudiante

# %%
# Aquí recogemos los números de un solo dígito que indican el número de hermanos/as
regex = re.compile(r'\b[0-79]\b')

# Creamos la variable HERMANOS y debe contener un solo dato
data['HERMANOS'] = data['observaciones'].apply(lambda x: regex.findall(str(x)))

data['HERMANOS'] = data['HERMANOS'].apply(lambda x: x[0] if len(x) > 0 else None)

# %% [markdown]
# Crear una variable dummy si el menor es beneficiario del programa y otra dummy si asiste a un colegio de jornada escolar completa.

# %%
# Ahora, le otorgamos la dummy considerando que contenga "Beneficiado" y le creamos su respectiva variable
data['BENEFICIARIO'] = np.where(data['observaciones'].str.contains('Beneficiado', na = False),1,0)

#Hacemos lo mismo con jornada completa
data['JORNADA'] = np.where(data['observaciones'].str.contains('completa', na = False),1,0)

# %% [markdown]
# Finalmente, para asegurarnos de tener la data completamente limpia corregimos detalles como mayúsculas o valores que contienen .0

# %%
# Debemos convertir age a string para corregir el error de .0
data['AGE'] = data['AGE'].astype(str)

# Aplicamos la expresión regular para eliminar el '.0' de la columna "AGE"
data['AGE'] = data['AGE'].str.replace(r'\.0$', '')

# Convertimos las columnas "GENDER" y "YEAR_OF_BIRTH" a string también
data['GENDER'] = data['GENDER'].astype(str)
data['YEAR_OF_BIRTH'] = data['YEAR_OF_BIRTH'].astype(str)

# Aplicamos la expresión
data['GENDER'] = data['GENDER'].str.replace(r'\.0$', '', regex=True)
data['YEAR_OF_BIRTH'] = data['YEAR_OF_BIRTH'].str.replace(r'\.0$', '', regex=True)

# Por último, como el primer nombre de NAME está en minúscula, convertimos todo a mayúscula
data['NAME'] = data['NAME'].str.replace(r'\w+', lambda x: x.group().upper())

# %% [markdown]
# Ahora sí, la data está completamente limpia!

# %%
data
# Out:
#                             NAME   BORN_DATE     AGE TYPE_ADM_SCHOOL GENDER  \
# 0              ROBERTO DAGA RIOS  1998-08-23      10               1      0
# 1              JOAN  BAEZ TEJADO  2004-02-22      15               0      0
# 2           MARC BASTARDES SOTO   1998-01-05      14               1      0
# 3       JOSEP ANGUERA VILAFRANCA  1999-02-21      16               1      0
# 4           JORDI RAYA   GAVILAN  1991-06-15      17               1      0
# 5          ARAN ALVAREZ FERNNDEZ  1993-09-03      12               1      0
# 6            JAVIER BENITEZ JOSE  1975-02-18      11               1      0
# 7         JESUS MENDIETA JIMENEZ  1993-08-16       9               0      0
# 8       GEMMA   LISTAN FIGUERAS   1992-07-16      11               1      1
# 9           ALBERT ARNALOT PUIG   2001-03-18       6               1      0
# 10        FANNY CIENFUEGOS PRADO  2000-08-28       7               0      1
# 11        BERTA GALOBART  GARCIA  1973-03-22       6               1      1
# 12       BERTA LPEZ GARRIGASSAIT  1998-05-19       5               1      1
# 13     MARIA ISABEL ALIGU BONVEH  2000-01-13      14               1      1
# 14              TONI MAS FRANCH   1995-03-26      16             NaN      0
# 15        JOAN MART ASENSIO VEGA  2003-03-08      16         miembro      0
# 16              CARLOS ACUA TORT  1979-07-03      14               1      0
# 17          DAVID   ALGU TRANCHO  1995-10-18  999999               1      0
# 18       CRISTINA BADIA CASTILLO  1990-02-08      11               1      1
# 19       CRISTINA ARISSA HERMOSO  2000-04-16      20               0      1
# 20     JOS ANTONIO BARALDS PARDO  1982-05-05      14               1      0
# 21            JORDI SUAREZ GARZN  1999-01-27       7               1      0
# 22         JUAN MANUEL GUTIERREZ  1995-10-18      15               1      0
# 23        DIANA  TORRES MARQUINA  2004-10-01   99999               0      1
# 24           JOSEPH AGUILAR SOTO  1998-12-18      12               1      0
# 25          PEDRO PALO DOMINGUEZ  1999-10-18      11               1      0
# 26       JOS FELICIANO SATURNINO  2000-06-18      10               0      0
# 27  SEBASTIAN GUTIERREZ CASIMIRO  1996-10-18      14               1      0
# 28          ANDREA PALOMINO RIOS  1997-05-18      13               1      1
# 29          HENRY PAULINO FLORES  2003-10-04       7               1      0
# 30           JUAN MENDOZA GARCIA  2004-10-18       6               1      0
# 31             JORGE  TAZO TAZO   1999-05-31      11               0      0
# 32    FRANCISCO GONZALES MELCHOR  2006-10-18       4               0      0
# 33        HUGO PACHECO  MANRIQUE  2003-01-10       7               0      0
# 34            JUAN MANUEL VARGAS  2008-10-18      12               1      0
# 35        JAQUELINE GARCIA MATOS  2012-10-18       8               1      1
# 36            FABIOLA MAGDA RIOS  2005-12-18      10               1      1
# 37         ROBERTO MENDOZA MATOS         NaN     nan             NaN    nan
#
#                          MAIL   DNI_NUMBER  \
# 0       albatros001@wandoo.es  04156597865
# 1          albert@intercom.es  02156597865
# 2        alien_10@intercom.es  01156597872
# 3          amores@hotmail.com  01156597872
# 4        antig56a@minorisa.es  01156597865
# 5   ballador_rios@hotmail.com  01156597872
# 6        balladora@altecom.es  01156597872
# 7        besugo13@minorisa.es  02156597865
# 8             bogart@terra.es  01156597898
# 9       carretero@intercom.es  01156597872
# 10            cela@altecom.es  01156597872
# 11           coco@hotmail.com  01156597872
# 12       conejo11@minorisa.es  01156597872
# 13           elisa@altecom.es  01156597872
# 14        encarna@hotmail.com  01156597872
# 15        groucho@intercom.es  01156597872
# 16          harpo@hotmail.com  01156597898
# 17    hispa@cataloniamail.com  01156597898
# 18          madonna@wandoo.es  01156597898
# 19        melanie@minorisa.es  01156597898
# 20     melquíades@hotmail.com  01156597898
# 21    abogados_15@hotmail.com  01156597898
# 22              bond@terra.es  01156597872
# 23          diana@intercom.es  01156597872
# 24   torresmarquina@gmail.com  02156597865
# 25     pdominguez@hotmail.com  01156597898
# 26       satur_seb15@terra.es  02156597865
# 27          mendoda@gmail.com  01156597898
# 28  palomino_rios@intercom.es  03156597865
# 29          mendoda@gmail.com  01156597898
# 30            jmg@hotmail.com  01156597872
# 31            tazoj@gmail.com  01156597865
# 32    gon_melchor@hotmail.com  01156597898
# 33          mendoda@gmail.com  01156597872
# 34            jmv@intercom.es  02156597865
# 35      jaqumatos@hotmail.com  01156597898
# 36          fmagt@intercom.es  01156597898
# 37      rmendozam@pucp.edu.pe          NaN
#
#                                         observaciones YEAR_OF_BIRTH  \
# 0                nombre correcto es Roberto daga rios          1998
# 1                                                 NaN          2004
# 2                                  edad correta es 15          1998
# 3                                                 NaN          1999
# 4   Beneficiado del programa Juntos, tiene 4 hermanos          1991
# 5                                                 NaN          1993
# 6              asiste a una II.EE de jornada completa          1975
# 7   nombre correcto es Jesus Mendieta Jimenez, asi...          1993
# 8                                                 NaN          1992
# 9                                                 NaN          2001
# 10          nombre correcto es Fanny Cienfuegos prado          2000
# 11                                                NaN          1973
# 12   tiene 4 hemanos, asiste a una II.EE de jornad...          1998
# 13                                                NaN          2000
# 14                                                NaN          1995
# 15                                                NaN          2003
# 16                                                NaN          1979
# 17   tiene 2 hermanos, Beneficiado del programa Ju...          1995
# 18                                                NaN          1990
# 19                                                NaN          2000
# 20  Asiste a una II.EE de jornada completa, edad c...          1982
# 21                                                NaN          1999
# 22                    Beneficiado del programa Juntos          1995
# 23                                                NaN          2004
# 24  Beneficiado del programa Juntos, edad correta ...          1998
# 25                                                NaN          1999
# 26                    Beneficiado del programa Juntos          2000
# 27                                                NaN          1996
# 28                                                NaN          1997
# 29            nombre correcto es Henry paulino flores          2003
# 30                                                NaN          2004
# 31                                 edad correta es 10          1999
# 32                                                NaN          2006
# 33                    Beneficiado del programa Juntos          2003
# 34                                                NaN          2008
# 35                                                NaN          2012
# 36   tiene 2 hermanas, asiste a una II.EE de jorna...          2005
# 37                                                NaN           nan
#
#            USUARIO HERMANOS  BENEFICIARIO  JORNADA
# 0      albatros001     None             0        0
# 1           albert     None             0        0
# 2         alien_10     None             0        0
# 3           amores     None             0        0
# 4         antig56a        4             1        0
# 5    ballador_rios     None             0        0
# 6        balladora     None             0        1
# 7         besugo13     None             0        1
# 8           bogart     None             0        0
# 9        carretero     None             0        0
# 10            cela     None             0        0
# 11            coco     None             0        0
# 12        conejo11        4             0        1
# 13           elisa     None             0        0
# 14         encarna     None             0        0
# 15         groucho     None             0        0
# 16           harpo     None             0        0
# 17           hispa        2             1        0
# 18         madonna     None             0        0
# 19         melanie     None             0        0
# 20      melquíades     None             0        1
# 21     abogados_15     None             0        0
# 22            bond     None             1        0
# 23           diana     None             0        0
# 24  torresmarquina     None             1        0
# 25      pdominguez     None             0        0
# 26     satur_seb15     None             1        0
# 27         mendoda     None             0        0
# 28   palomino_rios     None             0        0
# 29         mendoda     None             0        0
# 30             jmg     None             0        0
# 31           tazoj     None             0        0
# 32     gon_melchor     None             0        0
# 33         mendoda     None             1        0
# 34             jmv     None             0        0
# 35       jaqumatos     None             0        0
# 36           fmagt        2             0        1
# 37       rmandozam     None             0        0

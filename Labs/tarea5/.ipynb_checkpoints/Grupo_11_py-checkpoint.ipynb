# %% [markdown]
# ## Integrantes:

# %% [markdown]
# - Kevin Pareja (20196318)
#
# - Elian Tongombol (20196453)
#
# - Paola Aranda (20196052)
#
# - María Alejandra Colán (20190515)

# %%
import pandas as pd
import numpy as np
import warnings
import pyreadstat  # read .sav files
import pyreadr  # read dataser .Rdata

import seaborn as sns  # seaborn lirbary for plot
import matplotlib.pyplot as plt  # matplot
from matplotlib.lines import Line2D
import matplotlib.patches as mpatches

warnings.filterwarnings('ignore')

# %% [markdown]
# # PARTE 1:PLOT

# %% [markdown]
# ## Producción de hoja de coca por hectáreas

# %%
datos_xlsx = pd.read_excel("../../data/produccion_coca/6.1.1_-_Illicit_coca_bush_cultivation.xlsx")
datos_xlsx
# Out:
#    Global illicit cultivation of coca bush, 2009-2020 (hectares)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                   Bolivia (Plurinational State of)
# 4                                          Colombia a
# 5                                              Peru b
# 6                                               Total
# 7                                                 NaN
# 8   Sources: Plurinational State of Bolivia: natio...
# 9                      a)  Net area on 31 December.\n
# 10  b) Figures represent the area under coca culti...
# 11  d) The global coca cultivation figure was calc...
#
#              Unnamed: 1           Unnamed: 2           Unnamed: 3  \
# 0                   NaN                  NaN                  NaN
# 1   2009-01-04 00:00:00  2010-01-04 00:00:00  2011-01-04 00:00:00
# 2                   NaN                  NaN                  NaN
# 3                 30900                31000                27200
# 4                 73000                62000                64000
# 5                 59900                61200                62500
# 6                163800               154200               153700
# 7                   NaN                  NaN                  NaN
# 8                   NaN                  NaN                  NaN
# 9                   NaN                  NaN                  NaN
# 10                  NaN                  NaN                  NaN
# 11                  NaN                  NaN                  NaN
#
#              Unnamed: 4           Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0                   NaN                  NaN         NaN         NaN
# 1   2012-01-04 00:00:00  2013-01-05 00:00:00      2014.0      2015.0
# 2                   NaN                  NaN         NaN         NaN
# 3                 25300                23000     20400.0     20200.0
# 4                 48000                48000     69000.0     96000.0
# 5                 60400                49800     42900.0     40300.0
# 6                133700               120800    132300.0    156500.0
# 7                   NaN                  NaN         NaN         NaN
# 8                   NaN                  NaN         NaN         NaN
# 9                   NaN                  NaN         NaN         NaN
# 10                  NaN                  NaN         NaN         NaN
# 11                  NaN                  NaN         NaN         NaN
#
#     Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12
# 0          NaN         NaN          NaN          NaN          NaN
# 1       2016.0      2017.0       2018.0       2019.0       2020.0
# 2          NaN         NaN          NaN          NaN          NaN
# 3      23100.0     24500.0      23100.0      25500.0      29400.0
# 4     146000.0    171000.0     169000.0     154000.0     142800.0
# 5      43900.0     49900.0      54100.0      54700.0      61800.0
# 6     213000.0    245400.0     246200.0     234200.0     234200.0
# 7          NaN         NaN          NaN          NaN          NaN
# 8          NaN         NaN          NaN          NaN          NaN
# 9          NaN         NaN          NaN          NaN          NaN
# 10         NaN         NaN          NaN          NaN          NaN
# 11         NaN         NaN          NaN          NaN          NaN

# %%
datos= datos_xlsx.loc[[3,4,5],:]
datos= datos.iloc[:, 1:]
datos= datos.transpose()
datos= datos.rename(columns = {3:"Bolivia", 4:"Colombia", 5:"Peru"})
datos['year'] = pd.to_datetime(range(2009, 2021), format='%Y')
datos.reset_index(drop = True, inplace = True)
datos
# Out:
#     Bolivia  Colombia     Peru       year
# 0     30900     73000    59900 2009-01-01
# 1     31000     62000    61200 2010-01-01
# 2     27200     64000    62500 2011-01-01
# 3     25300     48000    60400 2012-01-01
# 4     23000     48000    49800 2013-01-01
# 5   20400.0   69000.0  42900.0 2014-01-01
# 6   20200.0   96000.0  40300.0 2015-01-01
# 7   23100.0  146000.0  43900.0 2016-01-01
# 8   24500.0  171000.0  49900.0 2017-01-01
# 9   23100.0  169000.0  54100.0 2018-01-01
# 10  25500.0  154000.0  54700.0 2019-01-01
# 11  29400.0  142800.0  61800.0 2020-01-01

# %%
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params)

fig, ax = plt.subplots(figsize=(8,5))

sns.lineplot(x= "year" , y= "Peru", data = datos, color="#c10534", marker = "o", legend=False, linestyle='--')
sns.lineplot(x= "year" , y= "Bolivia", data = datos, color="#92a4b6", marker = "s", legend=False, linestyle = '--')
sns.lineplot(x= "year" , y= "Colombia", data = datos, color="#26bb26", marker = "X", legend=False, linewidth = 0.5)

ax.set_xmargin(0)  # drop espacios vacios right, left 
plt.xlabel('Year')
plt.ylabel('Coca production')
plt.title("Figure 1: Cocoa Production in the Andean Region", size = 16)

plt.legend( labels = ["Peru", "Bolivia", "Colombia"])

# %% [markdown]
# # PARTE 2: Regex

# %% [markdown]
# 1. La base de datos metropolitano.xlsx posse información de latitud y longitud de las estaciones del metropiltano y dos lineas de alimentadores. Usar regex para cambiar el formato de las coordenadas a uno de coordenadas geográficos (i.e -11.25, -69.56). Guiese de la aplicación a las coordenadas del Capac Ñan usada en el script de python.

# %%
base1 = pd.read_excel(r"../../data/metropolitano.xlsx")
base1
# Out:
#       id  id_transport  cod_district       district transport_type  \
# 0      1             1      150112.0  independencia  metropolitano
# 1      2             1      150112.0  independencia  metropolitano
# 2      3             1      150112.0  independencia  metropolitano
# 3      4             1      150112.0  independencia  metropolitano
# 4      5             1      150112.0  independencia  metropolitano
# ..   ...           ...           ...            ...            ...
# 135  154             1           NaN            NaN  alimentador_8
# 136  155             1           NaN            NaN  alimentador_8
# 137  156             1           NaN            NaN  alimentador_8
# 138  157             1           NaN            NaN  alimentador_8
# 139  158             1           NaN            NaN  alimentador_8
#
#          station_name     sur_latitud  oeste_longitud
# 0         E. NARANJAL   11°58'51.19"S   77° 3'31.63"O
# 1           IZAGUIRRE   11°59'22.96"S   77° 3'25.30"O
# 2         PACIFICO E1   11°59'41.19"S   77° 3'21.84"O
# 3    INDEPENDENCIA E1   11°59'55.00"S   77° 3'18.79"O
# 4         JAZMINES E1    12° 0'7.88"S   77° 3'17.16"O
# ..                ...             ...             ...
# 135             ABTAO   12° 3'28.98"S   77° 1'20.22"O
# 136       ANDAHUAYLAS   12° 3'30.81"S   77° 1'34.43"O
# 137           ABANCAY   12° 3'32.80"S   77° 1'49.73"O
# 138  ESTACIÓN CENTRAL   12° 3'30.64"S   77° 2'11.10"O
# 139           HUANUCO   12° 3'27.47"S    77° 1'4.61"O
#
# [140 rows x 8 columns]

# %%
metropolitano = base1.copy()

# %%
# Limpiando la base de datos

data1 = metropolitano[metropolitano.id.isna()].reset_index(drop = True)
data2 = metropolitano[~ metropolitano.id.isna()].reset_index(drop = True)

# %%
data2
# Out:
#       id  id_transport  cod_district       district transport_type  \
# 0      1             1      150112.0  independencia  metropolitano
# 1      2             1      150112.0  independencia  metropolitano
# 2      3             1      150112.0  independencia  metropolitano
# 3      4             1      150112.0  independencia  metropolitano
# 4      5             1      150112.0  independencia  metropolitano
# ..   ...           ...           ...            ...            ...
# 135  154             1           NaN            NaN  alimentador_8
# 136  155             1           NaN            NaN  alimentador_8
# 137  156             1           NaN            NaN  alimentador_8
# 138  157             1           NaN            NaN  alimentador_8
# 139  158             1           NaN            NaN  alimentador_8
#
#          station_name     sur_latitud  oeste_longitud
# 0         E. NARANJAL   11°58'51.19"S   77° 3'31.63"O
# 1           IZAGUIRRE   11°59'22.96"S   77° 3'25.30"O
# 2         PACIFICO E1   11°59'41.19"S   77° 3'21.84"O
# 3    INDEPENDENCIA E1   11°59'55.00"S   77° 3'18.79"O
# 4         JAZMINES E1    12° 0'7.88"S   77° 3'17.16"O
# ..                ...             ...             ...
# 135             ABTAO   12° 3'28.98"S   77° 1'20.22"O
# 136       ANDAHUAYLAS   12° 3'30.81"S   77° 1'34.43"O
# 137           ABANCAY   12° 3'32.80"S   77° 1'49.73"O
# 138  ESTACIÓN CENTRAL   12° 3'30.64"S   77° 2'11.10"O
# 139           HUANUCO   12° 3'27.47"S    77° 1'4.61"O
#
# [140 rows x 8 columns]

# %%
data2.shape
# Out:
# (140, 8)

# %% [markdown]
# 2. En la carpeta estudiantes, ustedes encontrarán una base de datos llamada base_estudiantes.xlsx (Una base de datos muy sucia). La base de datos contiene información de estudiantes de la educación básica regular. Las variables son las siguientes: nombre, edad, fecha de nacimiento, tipo de administración de la institución educativa, género, correro electrónico, dni del apoderado, madre o padre, y una variable con observaciones.

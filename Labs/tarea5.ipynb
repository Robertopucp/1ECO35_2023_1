# %% [markdown]
# # Workgroup 5
# ## Autor: Grupo 4

# %%
import pandas as pd
import numpy as np
import warnings
import pyreadstat  # read .sav files
import pyreadr  # read dataser .Rdata
import openpyxl

import seaborn as sns  # seaborn lirbary for plot
import matplotlib.pyplot as plt  # matplot
from matplotlib.lines import Line2D
import matplotlib.patches as mpatches

warnings.filterwarnings('ignore')

# %%
datos = pd.read_excel('C:/Users/MISHELL/Documents/GitHub/1ECO35_2023_1/data/produccion_coca/6.1.1_-_Illicit_coca_bush_cultivation.xlsx', header=3, index_col=0)
datos
# Out:
#                                                     Unnamed: 1  Unnamed: 2  \
#   Bolivia (Plurinational State of)                     30900.0     31000.0
#   Colombia a                                           73000.0     62000.0
#   Peru b                                               59900.0     61200.0
#   Total                                               163800.0    154200.0
# NaN                                                        NaN         NaN
# Sources: Plurinational State of Bolivia: nation...         NaN         NaN
# a)  Net area on 31 December.\n                             NaN         NaN
# b) Figures represent the area under coca cultiv...         NaN         NaN
# d) The global coca cultivation figure was calcu...         NaN         NaN
#
#                                                     Unnamed: 3  Unnamed: 4  \
#   Bolivia (Plurinational State of)                     27200.0     25300.0
# ...

# %%
datost = datos.copy()
datost = datost.iloc[:3]
datost
# Out:
#                                      Unnamed: 1  Unnamed: 2  Unnamed: 3  \
#   Bolivia (Plurinational State of)      30900.0     31000.0     27200.0
#   Colombia a                            73000.0     62000.0     64000.0
#   Peru b                                59900.0     61200.0     62500.0
#
#                                      Unnamed: 4  Unnamed: 5  Unnamed: 6  \
#   Bolivia (Plurinational State of)      25300.0     23000.0     20400.0
#   Colombia a                            48000.0     48000.0     69000.0
#   Peru b                                60400.0     49800.0     42900.0
#
#                                      Unnamed: 7  Unnamed: 8  Unnamed: 9  \
#   Bolivia (Plurinational State of)      20200.0     23100.0     24500.0
#   Colombia a                            96000.0    146000.0    171000.0
#   Peru b                                40300.0     43900.0     49900.0
#
#                                      Unnamed: 10  Unnamed: 11  Unnamed: 12
# ...

# %%
datost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries,   Bolivia (Plurinational State of)  to   Peru b
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 1   3 non-null      float64
#  1   Unnamed: 2   3 non-null      float64
#  2   Unnamed: 3   3 non-null      float64
#  3   Unnamed: 4   3 non-null      float64
#  4   Unnamed: 5   3 non-null      float64
#  5   Unnamed: 6   3 non-null      float64
#  6   Unnamed: 7   3 non-null      float64
#  7   Unnamed: 8   3 non-null      float64
#  8   Unnamed: 9   3 non-null      float64
#  9   Unnamed: 10  3 non-null      float64
#  10  Unnamed: 11  3 non-null      float64
#  11  Unnamed: 12  3 non-null      float64
# dtypes: float64(12)
# memory usage: 312.0+ bytes

# %%
# Rename las  variables de año 
    
datost.rename(columns = {'Unnamed: 1':'2009', 'Unnamed: 2':'2010', 'Unnamed: 3':'2011',
                       'Unnamed: 4':'2012', 'Unnamed: 5':'2013', 'Unnamed: 6':'2014', 'Unnamed: 7':'2015', 
                          'Unnamed: 8':'2016', 'Unnamed: 9':'2017', 'Unnamed: 10':'2018', 'Unnamed: 11':'2019',
                          'Unnamed: 12':'2020'}, inplace = True)
datost
# Out:
#                                         2009     2010     2011     2012  \
#   Bolivia (Plurinational State of)   30900.0  31000.0  27200.0  25300.0
#   Colombia a                         73000.0  62000.0  64000.0  48000.0
#   Peru b                             59900.0  61200.0  62500.0  60400.0
#
#                                         2013     2014     2015      2016  \
#   Bolivia (Plurinational State of)   23000.0  20400.0  20200.0   23100.0
#   Colombia a                         48000.0  69000.0  96000.0  146000.0
#   Peru b                             49800.0  42900.0  40300.0   43900.0
#
#                                          2017      2018      2019      2020
#   Bolivia (Plurinational State of)    24500.0   23100.0   25500.0   29400.0
#   Colombia a                         171000.0  169000.0  154000.0  142800.0
#   Peru b                              49900.0   54100.0   54700.0   61800.0

# %%
datost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries,   Bolivia (Plurinational State of)  to   Peru b
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2009    3 non-null      float64
#  1   2010    3 non-null      float64
#  2   2011    3 non-null      float64
#  3   2012    3 non-null      float64
#  4   2013    3 non-null      float64
#  5   2014    3 non-null      float64
#  6   2015    3 non-null      float64
#  7   2016    3 non-null      float64
#  8   2017    3 non-null      float64
#  9   2018    3 non-null      float64
#  10  2019    3 non-null      float64
#  11  2020    3 non-null      float64
# dtypes: float64(12)
# memory usage: 312.0+ bytes

# %%
datostra = datost.transpose()
datostra
# Out:
#         Bolivia (Plurinational State of)     Colombia a    Peru b
# 2009                              30900.0       73000.0   59900.0
# 2010                              31000.0       62000.0   61200.0
# 2011                              27200.0       64000.0   62500.0
# 2012                              25300.0       48000.0   60400.0
# 2013                              23000.0       48000.0   49800.0
# 2014                              20400.0       69000.0   42900.0
# 2015                              20200.0       96000.0   40300.0
# 2016                              23100.0      146000.0   43900.0
# 2017                              24500.0      171000.0   49900.0
# 2018                              23100.0      169000.0   54100.0
# 2019                              25500.0      154000.0   54700.0
# 2020                              29400.0      142800.0   61800.0

# %%
datostra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 2009 to 2020
# Data columns (total 3 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0     Bolivia (Plurinational State of)   12 non-null     float64
#  1     Colombia a                         12 non-null     float64
#  2     Peru b                             12 non-null     float64
# dtypes: float64(3)
# memory usage: 684.0+ bytes

# %%
# Rename las  variables de año 
    
nuevos_nombres = ['Bolivia','Colombia','Peru']
datostra.columns = nuevos_nombres

datostra
# Out:
#       Bolivia  Colombia     Peru
# 2009  30900.0   73000.0  59900.0
# 2010  31000.0   62000.0  61200.0
# 2011  27200.0   64000.0  62500.0
# 2012  25300.0   48000.0  60400.0
# 2013  23000.0   48000.0  49800.0
# 2014  20400.0   69000.0  42900.0
# 2015  20200.0   96000.0  40300.0
# 2016  23100.0  146000.0  43900.0
# 2017  24500.0  171000.0  49900.0
# 2018  23100.0  169000.0  54100.0
# 2019  25500.0  154000.0  54700.0
# 2020  29400.0  142800.0  61800.0

# %%
# Crear la variable year
anos = list(range(2009,2021))
datostra = datostra.assign(year=anos)

datostra
# Out:
#       Bolivia  Colombia     Peru  year
# 2009  30900.0   73000.0  59900.0  2009
# 2010  31000.0   62000.0  61200.0  2010
# 2011  27200.0   64000.0  62500.0  2011
# 2012  25300.0   48000.0  60400.0  2012
# 2013  23000.0   48000.0  49800.0  2013
# 2014  20400.0   69000.0  42900.0  2014
# 2015  20200.0   96000.0  40300.0  2015
# 2016  23100.0  146000.0  43900.0  2016
# 2017  24500.0  171000.0  49900.0  2017
# 2018  23100.0  169000.0  54100.0  2018
# 2019  25500.0  154000.0  54700.0  2019
# 2020  29400.0  142800.0  61800.0  2020

# %%
datostra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 2009 to 2020
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Bolivia   12 non-null     float64
#  1   Colombia  12 non-null     float64
#  2   Peru      12 non-null     float64
#  3   year      12 non-null     int64
# dtypes: float64(3), int64(1)
# memory usage: 780.0+ bytes

# %%
datostra['Year']  = pd.to_datetime(datostra['year'])  # pandas para pasar una varaible a formato fecha
datostra
# Out:
#       Bolivia  Colombia     Peru  year                          Year
# 2009  30900.0   73000.0  59900.0  2009 1970-01-01 00:00:00.000002009
# 2010  31000.0   62000.0  61200.0  2010 1970-01-01 00:00:00.000002010
# 2011  27200.0   64000.0  62500.0  2011 1970-01-01 00:00:00.000002011
# 2012  25300.0   48000.0  60400.0  2012 1970-01-01 00:00:00.000002012
# 2013  23000.0   48000.0  49800.0  2013 1970-01-01 00:00:00.000002013
# 2014  20400.0   69000.0  42900.0  2014 1970-01-01 00:00:00.000002014
# 2015  20200.0   96000.0  40300.0  2015 1970-01-01 00:00:00.000002015
# 2016  23100.0  146000.0  43900.0  2016 1970-01-01 00:00:00.000002016
# 2017  24500.0  171000.0  49900.0  2017 1970-01-01 00:00:00.000002017
# 2018  23100.0  169000.0  54100.0  2018 1970-01-01 00:00:00.000002018
# 2019  25500.0  154000.0  54700.0  2019 1970-01-01 00:00:00.000002019
# 2020  29400.0  142800.0  61800.0  2020 1970-01-01 00:00:00.000002020

# %%
datostra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 2009 to 2020
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Bolivia   12 non-null     float64
#  1   Colombia  12 non-null     float64
#  2   Peru      12 non-null     float64
#  3   year      12 non-null     int64
#  4   Year      12 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(1)
# memory usage: 876.0+ bytes

# %%
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params)  # theme de fondo blanco 
fig, ax = plt.subplots(figsize=(7,4))

# usando seaborn 

sns.lineplot(x= "year" , y= "Peru", data = datostra, color="#bd0003", marker = 'o', linewidth = 1.6, linestyle='--')

sns.lineplot(x= "year" , y= "Bolivia", data = datostra, color="#d3d3d3", marker='s', linewidth = 1.8, linestyle='-')

sns.lineplot(x= "year" , y= "Colombia", data = datostra, color="#89d631", marker = "X", linewidth = 1.5)

# Leyenda
plt.legend(labels=['Peru', 'Bolivia', 'Colombia'],loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)

# ajustando rango del eje y,x
plt.ylim(0,190000)  
plt.xlim(2009,2020)

# Labels en los ejes
plt.xlabel('year')
plt.ylabel('Coca Production')

# Agregando título
plt.title('Figure 1: Coca production in the Andean region')

# agregando pie de página
ax.text(2009,-100,"Notes: This graph shows coca production per year in the Andean region using UNODC data",
        color = 'black', size = 12, ha='left')
# Out:
# Text(2009, -100, 'Notes: This graph shows coca production per year in the Andean region using UNODC data')

# %% [markdown]
# # Tarea 1

# %% [markdown]
# ## Integrantes:

# %% [markdown]
# Kevin Pareja (20196318)
#
# Elian Tongombol (20196453)
#
# Paola Aranda (20196052)
#
# María Alejandra Colán (20190515)

# %% [markdown]
# ### 1. F-string
#
# Use F-string para crear el siguiente texto: "Facultad de Ciencias Sociales \ 2023"
# Use el año como la variable en la estructura f-string

# %%
#Creo la variable año, imprimimos la variable año acompañado del texto Facultad de Ciencias Sociales.
año = 2023
print(f'Facultad de Ciencias Sociales {año}')
# Out:
# Facultad de Ciencias Sociales 2023

# %% [markdown]
# ### 2. Lista
#
# Crear una lista de países miembros del acuerdo de la Alianza del Pacífico: Australia, Brunei Darussalam, Canadá, Corea, Chile, China, Estados Unidos, Filipinas, Hong Kong, Indonesia, Japón, Malasia.
#
# Use la lista creada para obtener a Chile.
# Use la lista creada para obtener a Malasia.
# Use la lista creada para obtener una lista de países desde China hasta Indonesia.

# %%
#Creamos una lista llamada países.
paises = ["Australia", "Brunei Darussalam", "Canadá", "Corea", "Chile", "China", "Estados Unidos", "Filipinas",
         "Hong Kong", "Indonesia", "Japón", "Malasia"]

# %%
#Imprimimos la posición 4 de la lista "paises" (python comienza a contar desde 0).
print(paises[4])
# Out:
# Chile

# %%
#Imprimimos el último elemento de la lista.
print(paises[-1])
# Out:
# Malasia

# %%
#Imprimimos un conjunto de elementos de la lista. 
print(paises[5:10])
# Out:
# ['China', 'Estados Unidos', 'Filipinas', 'Hong Kong', 'Indonesia']

# %% [markdown]
# ### 3. Diccionario
# Replique el siguiente diccionario
#
# ![image.png](attachment:image.png)

# %%
dicc = {'Numero atómico': [1, 6, 47, 88],
        'Masa atómica': [1.008, 12.011, 107.87, 226], 
        'Familia': ['No metal', 'No metal', 'Metal', 'Metal']}

# %% [markdown]
# Extraer las palabras "Metal" y el numero 47

# %%
dicc
# Out:
# {'Numero atómico': [1, 6, 47, 88],
#  'Masa atómica': [1.008, 12.011, 107.87, 226],
#  'Familia': ['No metal', 'No metal', 'Metal', 'Metal']}

# %%
print(dicc.get('Familia')[2:])
# Out:
# ['Metal', 'Metal']

# %%
print(dicc.get('Numero atómico')[2])
# Out:
# 47

# %% [markdown]
# Añade un Key llamado books que almacene los titulos de 3 libros.

# %%
dicc.update({'books': ['Travesuras de la niña mala', 'Rayuela', 'La tía Julia']})

# %%
dicc
# Out:
# {'Numero atómico': [1, 6, 47, 88],
#  'Masa atómica': [1.008, 12.011, 107.87, 226],
#  'Familia': ['No metal', 'No metal', 'Metal', 'Metal'],
#  'books': ['Travesuras de la niña mala', 'Rayuela', 'La tía Julia']}

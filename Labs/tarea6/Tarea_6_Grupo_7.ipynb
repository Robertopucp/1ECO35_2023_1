# %%
# !pip install ghostscript
# !pip install camelot-py[cv]
# !pip install excalibur-py
# !apt install ghostscript python3-tk

# !pip install PdfReader
# !pip install --upgrade PyPDF2==2.12.1

# necesitamos una versión anterior de PyPDF2 para que cmelot pueda leer archivos PDF

import camelot as cm  # libreria de camelot
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import os
from PyPDF2 import PdfFileReader
import re # expresiones regulares
# Out:
# ...
# zsh:1: no matches found: camelot-py[cv]
# ...
#   Using cached excalibur_py-0.4.3-py3-none-any.whl (1.5 MB)
# ...
#   Using cached configparser-3.5.3-py3-none-any.whl (21 kB)
# ...
#   Using cached celery-5.3.0-py3-none-any.whl (420 kB)
# ...
#   Using cached Werkzeug-0.16.1-py2.py3-none-any.whl (327 kB)
# ...
#   Using cached camelot_py-0.11.0-py3-none-any.whl (40 kB)
# ...
#   Using cached pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
# ...
#   Using cached pypdf-3.9.1-py3-none-any.whl (249 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 MB 10.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.5/198.5 kB 6.2 MB/s eta 0:00:00
# ...

# %%
tables = cm.read_pdf("/Users/kubo/Documents/GitHub/1ECO35_2023_1/data/JEC/G7_SAN_MARTIN.pdf")

print (tables)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/camelot/ext/ghostscript/_gsprint.py:260
#     259 try:
# --> 260     libgs = cdll.LoadLibrary("libgs.so")
#     261 except OSError:
#     262     # shared object file not found
#
# File ~/anaconda3/lib/python3.10/ctypes/__init__.py:452, in LibraryLoader.LoadLibrary(self, name)
#     451 def LoadLibrary(self, name):
# --> 452     return self._dlltype(name)
#
# File ~/anaconda3/lib/python3.10/ctypes/__init__.py:374, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     373 if handle is None:
# --> 374     self._handle = _dlopen(self._name, mode)
#     375 else:
#
# ...

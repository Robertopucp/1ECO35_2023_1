# %%
for i in range(400):                        #simularemos una compras hasta 400 soles, para poder simular los valres 
    
    if (i <= 100) :
        print("Compra de",i , "soles y pago en efectivo", i, "soles", "\n")
    if (100 < i <= 300) :
        print("Compra de",i, "soles y pago con tarjeta de débito", i, "soles", "\n")
    if (300 < i) : 
        y=i*(1-0.1)
        print("Compra de",i , "soles y pago con tarjeta de crédito un monto de",y , "soles", "\n")
# Out:
# Compra de 0 soles y pago en efectivo 0 soles
#
# Compra de 1 soles y pago en efectivo 1 soles
#
# Compra de 2 soles y pago en efectivo 2 soles
#
# Compra de 3 soles y pago en efectivo 3 soles
#
# Compra de 4 soles y pago en efectivo 4 soles
#
# Compra de 5 soles y pago en efectivo 5 soles
#
# Compra de 6 soles y pago en efectivo 6 soles
#
# Compra de 7 soles y pago en efectivo 7 soles
#
# Compra de 8 soles y pago en efectivo 8 soles
#
# Compra de 9 soles y pago en efectivo 9 soles
#
# Compra de 10 soles y pago en efectivo 10 soles
#
# Compra de 11 soles y pago en efectivo 11 soles
#
# Compra de 12 soles y pago en efectivo 12 soles
#
# Compra de 13 soles y pago en efectivo 13 soles
#
# Compra de 14 soles y pago en efectivo 14 soles
#
# Compra de 15 soles y pago en efectivo 15 soles
#
# Compra de 16 soles y pago en efectivo 16 soles
#
# Compra de 17 soles y pago en efectivo 17 soles
#
# Compra de 18 soles y pago en efectivo 18 soles
#
# Compra de 19 soles y pago en efectivo 19 soles
#
# ...

# %%
for i in range(400): 
    
     if (i <= 100) :
        y= i**(1/2)
        print(y)
if (100 < i <= 300) :
        y= i-5
        print(y)
else :
        print("50")
# Out:
# 0.0
# 1.0
# 1.4142135623730951
# 1.7320508075688772
# 2.0
# 2.23606797749979
# 2.449489742783178
# 2.6457513110645907
# 2.8284271247461903
# 3.0
# 3.1622776601683795
# 3.3166247903554
# 3.4641016151377544
# 3.605551275463989
# 3.7416573867739413
# 3.872983346207417
# 4.0
# 4.123105625617661
# 4.242640687119285
# 4.358898943540674
# 4.47213595499958
# 4.58257569495584
# 4.69041575982343
# 4.795831523312719
# 4.898979485566356
# 5.0
# 5.0990195135927845
# 5.196152422706632
# 5.291502622129181
# 5.385164807134504
# 5.477225575051661
# 5.5677643628300215
# 5.656854249492381
# 5.744562646538029
# 5.830951894845301
# 5.916079783099616
# 6.0
# 6.082762530298219
# 6.164414002968976
# 6.244997998398398
# 6.324555320336759
# 6.4031242374328485
# 6.48074069840786
# 6.557438524302
# 6.6332495807108
# 6.708203932499369
# 6.782329983125268
# 6.855654600401044
# 6.928203230275509
# 7.0
# 7.0710678118654755
# 7.14142842854285
# 7.211102550927978
# 7.280109889280518
# 7.3484692283495345
# ...

# %%
#BUCLES
listas = [100, 152, -1, 8, 12, 156.35, -10, 100, -0.5, 30, 1050, 7, -10]
for i in range(12):
    if (0 < listas[i] < 1000): 
        print("La utilidad neta anual es", listas[i], "millones ", "\n")
# Out:
# La utilidad neta anual es 100 millones
#
# La utilidad neta anual es 152 millones
#
# La utilidad neta anual es 8 millones
#
# La utilidad neta anual es 12 millones
#
# La utilidad neta anual es 156.35 millones
#
# La utilidad neta anual es 100 millones
#
# La utilidad neta anual es 30 millones
#
# La utilidad neta anual es 7 millones

# %%
listas = [100, 152, -1, 8, 12, 156.35, -10, 100, -0.5, 30, 1050, 7, -10]
for i in range(12):
    if (listas[i] > 1000):
        break 
    if (listas[i] > 0): 
        print("La utilidad neta anual es", listas[i], "millones ", "\n")
# Out:
# La utilidad neta anual es 100 millones
#
# La utilidad neta anual es 152 millones
#
# La utilidad neta anual es 8 millones
#
# La utilidad neta anual es 12 millones
#
# La utilidad neta anual es 156.35 millones
#
# La utilidad neta anual es 100 millones
#
# La utilidad neta anual es 30 millones

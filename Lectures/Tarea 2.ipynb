# %%
 monto_compra3 = float(input("Ingrese el monto de la compra: "))

if monto_compra3 > 300: 
    monto_final3 = 0.9 * monto_compra3 #es la cantidad final a pagar después del descuento del 10%
    
    print ("Compra de", monto_final3, "soles y pago con tarjeta de crédito")
    

else: 
    monto_compra3 = print (monto_compra3)

    
####

monto_compra2 = float(input("Ingrese el monto de la compra: "))

if 100 < monto_compra2 < 300: 
    monto_final2 = 1 * monto_compra2
    
    print ("Compra de", monto_final2, "soles y pago con tarjeta de débito")
    

else: 
    monto_compra2 = print (monto_compra2)
    
    
###


monto_compra1 = float(input("Ingrese el monto de la compra: "))

if monto_compra1 < 100: 
    monto_final1 = 1 * monto_compra1
    
    print ("Compra de", monto_final1, "soles y pago con efectivo")
    

else: 
    monto_compra1 = print (monto_compra1)


############

monto_compra = float(input("Ingrese el monto de la compra: "))

if monto_compra > 300:
    monto_final = 0.9 * monto_compra
    print("Compra de", monto_final, "soles y pago con tarjeta de crédito")
    
elif 100 < monto_compra < 300:
    monto_final = 1 * monto_compra
    print("Compra de", monto_final, "soles y pago con tarjeta de débito")
    
else:
    monto_final = 1 * monto_compra
    print("Compra de", monto_final, "soles y pago con efectivo") 

######

x_b = float(input("Ingrese el monto de la compra: "))

if x_b > 300:
    x = 50 
    print (x)

elif 100 < x_b < 300: 
    x = x_b - 5
    print (x)

else: 
    x = x_b ** 0.5
    print(x)

#######

u_n = [100, 152, -1 , 8, 12, 156,35, -10, 100, -0.5, 30, 1050 , 7, -10]

# acotamos los valores de las utilidades a mayores a 0, pero menores a 1000 

u_n_positivas_menores_a_1000 = [x for x in u_n if 0 < x < 1000]

# imprimimos la frase que nos piden con los valores acotados

for utilidad_final in u_n_positivas_menores_a_1000: 
    print ("La utilidad neta anual es", utilidad_final)
# Out:
# Ingrese el monto de la compra: 300
# 300.0
# Ingrese el monto de la compra: 200
# Compra de 200.0 soles y pago con tarjeta de débito
# Ingrese el monto de la compra: 120
# 120.0
# Ingrese el monto de la compra: 3
# Compra de 3.0 soles y pago con efectivo

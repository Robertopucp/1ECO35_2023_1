# %% [markdown]
# #  Laboratorio 5 - Python
# ## @author: Roberto Mendoza

# %% [markdown]
# - <a href='#1.0'> 1.0 Gráfico de barras  </a>
# - <a href='#1.1'> 1.1 Colores  </a>
# - <a href='#1.2'> 1.2 Stacked bar   </a>
# - <a href='#2.0'> 2.0 Histogramas   </a>
# - <a href='#2.1'> 2.1 Subgráficos de histogramas   </a>
# - <a href='#3.0'> 3.0 Series de tiempo (line)   </a>
# - <a href='#4.0'> 4.0 Diagrama de dispersión (Binsplot)   </a>

# %%
import pandas as pd
import numpy as np
import warnings
import pyreadstat  # read .sav files
import pyreadr  # read dataser .Rdata

import seaborn as sns  # seaborn lirbary for plot
import matplotlib.pyplot as plt  # matplot
from matplotlib.lines import Line2D
import matplotlib.patches as mpatches

warnings.filterwarnings('ignore')

# %%
data1, meta =  pyreadstat.read_sav( r"../../data/Riesgo_morosidad.sav")
data1
# Out:
#       edad  sexo  nrodepen  fonopart  fonolab  autovaluo  esaval  tieneaval  \
# 0     44.0   2.0       3.0       2.0      2.0        1.0     1.0        1.0
# 1     77.0   2.0       4.0       2.0      2.0        1.0     1.0        2.0
# 2     59.0   2.0       5.0       1.0      1.0        1.0     2.0        1.0
# 3     35.0   2.0       5.0       1.0      2.0        1.0     1.0        1.0
# 4     65.0   2.0       0.0       2.0      1.0        1.0     2.0        1.0
# ...    ...   ...       ...       ...      ...        ...     ...        ...
# 8466  57.0   2.0       5.0       1.0      1.0        1.0     2.0        2.0
# 8467  57.0   2.0       3.0       2.0      1.0        1.0     1.0        2.0
# 8468  64.0   2.0       1.0       2.0      1.0        2.0     1.0        1.0
# 8469  67.0   1.0       0.0       2.0      1.0        2.0     1.0        2.0
# 8470  69.0   2.0       1.0       1.0      1.0        1.0     2.0        1.0
#
#       antiguedad  tiporenta  dpto  morosidad
# ...

# %%
datospss = data1.copy()

# %%
# etiquetas de variable 

var_labels = dict(zip(meta.column_names, meta.column_labels))
var_labels
# Out:
# {'edad': 'Edad',
#  'sexo': 'Sexo',
#  'nrodepen': 'Número de Dependientes',
#  'fonopart': '¿Tiene teléfono particular?',
#  'fonolab': '¿Tiene teléfono en el trabajo?',
#  'autovaluo': '¿Presenta autovaluo?',
#  'esaval': '¿Es aval de otros clientes?',
#  'tieneaval': '¿Tiene aval?',
#  'antiguedad': 'Antiguedad en años',
#  'tiporenta': 'Tipo de renta',
#  'dpto': 'Departamento',
#  'morosidad': 'Morosidad'}

# %%
# etiqueta de valores
meta.variable_value_labels
# Out:
# {'sexo': {1.0: 'Femenino', 2.0: 'Masculino'},
#  'fonopart': {1.0: 'No', 2.0: 'Si'},
#  'fonolab': {1.0: 'No', 2.0: 'Si'},
#  'autovaluo': {1.0: 'No', 2.0: 'Si'},
#  'esaval': {1.0: 'No', 2.0: 'Si'},
#  'tieneaval': {1.0: 'No', 2.0: 'Si'},
#  'tiporenta': {2.0: 'Fijo', 3.0: 'Variable'},
#  'dpto': {1.0: 'Lima',
#   2.0: 'Trujillo',
#   3.0: 'Arequipa',
#   4.0: 'Cusco',
#   5.0: 'Ica',
#   6.0: 'Piura'},
#  'morosidad': {1.0: 'No Moroso', 2.0: 'Moroso'}}

# %% [markdown]
# ## <a id='1.0'> 1.0 Gráfico de barras  </a>

# %%
# De matplot (modulo) 
# fig (objeto figura), ax (ejes) = plt.subplots( figsize = (7,4))

fig, ax = plt.subplots( figsize=(7,7) )
# gglplot() + aes(x = , y =)

# %%
fig, ax = plt.subplots( figsize=(7,4) )

# countplot de la libreria seaborn 

# import seaborn as sns

sns.countplot( x="morosidad", data=datospss)

# 1 NO moroso, 2 Moroso
# Out:
# <AxesSubplot:xlabel='morosidad', ylabel='count'>

# %%
datospss.morosidad.value_counts()
# Out:
# 1.0    5260
# 2.0    3211
# Name: morosidad, dtype: int64

# %%
fig, ax = plt.subplots( figsize=(7,4) )

sns.countplot( x="morosidad", data=datospss )  # sns.countplot(x = , data = base de datos)

ax.set_xticklabels(["No Moroso", "Moroso"], size=12) # cambiar las etiquetas en el eje x

# titulos en los ejes
# usando librearia matplot (plt)

plt.ylabel('')
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
# Cambio de Orientación

fig, ax = plt.subplots( figsize=(7,4) )

sns.countplot( y="morosidad", data=datospss )

ax.set_yticklabels(["No Moroso", "Moroso"], size=11)
plt.ylabel('')
plt.xlabel('')


# theme (mas abajo)
# Out:
# Text(0.5, 0, '')

# %%
# añadiendo subtitulos y titulo de gráfico

fig, ax = plt.subplots( figsize=(7,4) )

sns.countplot( x="morosidad", data=datospss )

ax.set_xticklabels(["No Moroso", "Moroso"], size=11)
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Condición de la morosidad')
plt.title("Gráfico de Barras \n de \n morosidad", size = 12)
# Out:
# Text(0.5, 1.0, 'Gráfico de Barras \n de \n morosidad')

# %%
# ajustanto el tamaño de los susbtitulos y titulos

fig, ax = plt.subplots( figsize=(7,4) )

sns.countplot( x="morosidad", data=datospss )

ax.set_xticklabels(["No Moroso", "Moroso"], size=11)
plt.ylabel('Frecuencia absoluta', size = 10)
plt.xlabel('Condición de la morosidad', size = 10)
plt.title("Gráfico de barras de morosidad", size = 18)
# Out:
# Text(0.5, 1.0, 'Gráfico de barras de morosidad')

# %%
# Asignando colores diferentes

fig, ax = plt.subplots( figsize=(7,4) )

sns.countplot( y="morosidad", data=datospss , palette=['lightblue', 'lightgreen']) 

# pallete = lista el nombre de los colores

ax.set_yticklabels(["No Moroso", "Moroso"], size=11)
plt.xlabel('Frecuencia absoluta', size = 8)
plt.ylabel('Condición de la morosidad', size = 8)
plt.title("Gráfico de barras de morosidad", size = 18)
# Out:
# Text(0.5, 1.0, 'Gráfico de barras de morosidad')

# %%
# Usando los colores RGB (UNIVERSAL)

# RGB (red, green, blue)

fig, ax = plt.subplots( figsize=(7,4) )

sns.countplot( x="morosidad", data=datospss , palette=["#FC4040", "#4DE26B"], edgecolor = "#000000")


# edge color: color de borde 

ax.set_xticklabels(["No Moroso", "Moroso"], size=11)
plt.ylabel('Frecuencia absoluta', size = 8)
plt.xlabel('Condición de la morosidad', size = 8)
plt.title("Gráfico de barras de morosidad", size = 18)


# save plot

fig.savefig(r'../../output/plots/plot_bar_morosidad.png', dpi=800, bbox_inches='tight')

# bbox_inches='tight' : titulos, subtitulos, anotaciones, leyenda serán visibles en la imagen

# %% [markdown]
# ## <a id='1.1'> 1.1 Colores  </a>
#
# https://www.rapidtables.com/web/color/RGB_Color.html

# %% [markdown]
# ## <a id='1.2'> 1.2 Stacked bar  </a>

# %%
base = pd.crosstab(datospss.tiporenta, datospss.morosidad) #.pivot(index = 'tiporenta', columns = 'morosidad', values = 'cantidad')
base
# Out:
# morosidad   1.0   2.0
# tiporenta
# 2.0        2539  1237
# 3.0        2721  1974

# %%
fig, ax = plt.subplots( figsize=(5,4) )

# matplot

base.plot( kind='bar', stacked=True, title='Situación de la Morosidad según Tipo de Renta',
          colormap='tab10' , ax = ax)  # colormap 

plt.xlabel('Tipo de Renta')
plt.ylabel('Frecuencia')
ax.set_xticklabels(["Fijo", "Variable"], size=11, rotation=0)

plt.legend( labels = ["No moroso", "Moroso"] , bbox_to_anchor=(1.4, 0.5))

fig.savefig(r'../../output/plots/plot_bar_morosidad_renta.png', dpi=800, bbox_inches='tight') # dpi calidad del gráfico

# %% [markdown]
# - Colores combinados
#
# https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %% [markdown]
# ## Stacked Bar Plot en proporción

# %%
base = pd.crosstab(datospss.tiporenta, datospss.morosidad, normalize="index") #.pivot(index = 'tiporenta', columns = 'morosidad', values = 'cantidad')
base
# Out:
# morosidad       1.0       2.0
# tiporenta
# 2.0        0.672405  0.327595
# 3.0        0.579553  0.420447

# %%
fig, ax = plt.subplots( figsize=(5,4) )

base.plot( kind='barh', stacked=True, title='Situación de la Morosidad según Tipo de Renta (%)',
          colormap='tab10' , ax = ax)

plt.xlabel('Frecuencia relativa')
plt.ylabel('Tipo de Renta')
plt.legend(loc="lower left", bbox_to_anchor=(0.5 , 0.65))
ax.set_yticklabels(["Fijo", "Variable"], size=11, rotation=0)

plt.legend(labels = ["No moroso", "Moroso"], bbox_to_anchor=(1, 0.65))

# %% [markdown]
# ## <a id='2.0'> 2.0 Histogramas  </a>

# %%
fig, ax = plt.subplots(figsize=(8,5))

sns.histplot(data = datospss,
            x = 'edad',
            alpha = 0.8, # transparencia 
            edgecolor="black", # color de los bordes de cada barra
            linewidth=0.8  # ancho de los bordes de cada barra
            )
# Out:
# <AxesSubplot:xlabel='edad', ylabel='Count'>

# %%
fig, ax = plt.subplots(figsize=(8,5))

sns.histplot(data = datospss,
            x = 'edad',
            alpha = 0.7,
            edgecolor="0.2",
            linewidth=1,
             bins = 3 # 100 segmentos del rango de edad 
            )

plt.xlabel('Edad')
plt.ylabel('Frecuencia absoluta')

# al altura de la barra indica la cantidad de personas que son aprte de cada intervalo
# Out:
# Text(0, 0.5, 'Frecuencia absoluta')

# %%
# Histograma de la edad según situación de morosidad 

fig, ax = plt.subplots(figsize=(8,5))

sns.histplot(data = datospss,
            x = 'edad',
            alpha = 0.7,
            edgecolor="0.2",
            linewidth=1,
            hue = 'morosidad', # agrupar la muestra 
            palette=["#E69F00", "#56B4E9"] # RGB
            )

plt.xlabel('Edad')
plt.ylabel('Frecuencia absoluta')
plt.legend( labels = ["Moroso", "No moroso"])

# %% [markdown]
# ## <a id='2.1'> 2.1 Subgráficos de histogramas  </a>

# %%
datospss.loc[datospss.dpto == 1, "region"] = "Lima"
datospss.loc[datospss.dpto == 2, "region"] = "Trujillo"
datospss.loc[datospss.dpto == 3, "region"] = "Arequipa"
datospss.loc[datospss.dpto == 4, "region"] = "Cusco"
datospss.loc[datospss.dpto == 5, "region"] = "Ica"
datospss.loc[datospss.dpto == 6, "region"] = "Piura"

# %%
datospss.region.value_counts(normalize = True)
# Out:
# Lima        0.590249
# Trujillo    0.118050
# Arequipa    0.118050
# Cusco       0.059025
# Ica         0.059025
# Piura       0.055601
# Name: region, dtype: float64

# %%
# histograma con columnas estandarizadas

figure = sns.displot( data = datospss, x = 'edad', col = 'region', 
            col_wrap = 3
           )


figure.set_titles("{col_name}", size = 14)  # colcoca nombre de cada gráfico según nombre de región

# %%
# Cada histograma por separado

figure = sns.displot( data = datospss, x = 'edad', col = 'region', 
            col_wrap = 3,
    facet_kws = {'sharex' : False,   # no compartir rango del eje X
        'sharey' : False }  #  compartir rango del eje Y
           )

figure.set_titles("{col_name}", size = 14)

# %% [markdown]
# ## <a id='3.0'> 3.0 Series de tiempo (line)  </a>

# %%
economics = pd.read_csv("../../data/economics.csv")
economics
# Out:
#            date      pce         pop  psavert  uempmed  unemploy
# 0    1967-07-01    506.7  198712.000     12.6      4.5      2944
# 1    1967-08-01    509.8  198911.000     12.6      4.7      2945
# 2    1967-09-01    515.6  199113.000     11.9      4.6      2958
# 3    1967-10-01    512.2  199311.000     12.9      4.9      3143
# 4    1967-11-01    517.4  199498.000     12.8      4.7      3066
# ..          ...      ...         ...      ...      ...       ...
# 569  2014-12-01  12062.0  319746.157      7.6     12.9      8717
# 570  2015-01-01  12046.0  319928.646      7.7     13.2      8903
# 571  2015-02-01  12082.4  320074.511      7.9     12.9      8610
# 572  2015-03-01  12158.3  320230.786      7.4     12.0      8504
# 573  2015-04-01  12193.8  320402.295      7.6     11.5      8526
#
# [574 rows x 6 columns]

# %%
economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      574 non-null    object
#  1   pce       574 non-null    float64
#  2   pop       574 non-null    float64
#  3   psavert   574 non-null    float64
#  4   uempmed   574 non-null    float64
#  5   unemploy  574 non-null    int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 27.0+ KB

# %%
# extraemos el año
economics['year']  = pd.to_datetime(economics['date'])  # pandas para pasar una varaible a formato fecha

# %%
economics
# Out:
#            date      pce         pop  psavert  uempmed  unemploy       year
# 0    1967-07-01    506.7  198712.000     12.6      4.5      2944 1967-07-01
# 1    1967-08-01    509.8  198911.000     12.6      4.7      2945 1967-08-01
# 2    1967-09-01    515.6  199113.000     11.9      4.6      2958 1967-09-01
# 3    1967-10-01    512.2  199311.000     12.9      4.9      3143 1967-10-01
# 4    1967-11-01    517.4  199498.000     12.8      4.7      3066 1967-11-01
# ..          ...      ...         ...      ...      ...       ...        ...
# 569  2014-12-01  12062.0  319746.157      7.6     12.9      8717 2014-12-01
# 570  2015-01-01  12046.0  319928.646      7.7     13.2      8903 2015-01-01
# 571  2015-02-01  12082.4  320074.511      7.9     12.9      8610 2015-02-01
# 572  2015-03-01  12158.3  320230.786      7.4     12.0      8504 2015-03-01
# 573  2015-04-01  12193.8  320402.295      7.6     11.5      8526 2015-04-01
#
# [574 rows x 7 columns]

# %%
economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      574 non-null    object
#  1   pce       574 non-null    float64
#  2   pop       574 non-null    float64
#  3   psavert   574 non-null    float64
#  4   uempmed   574 non-null    float64
#  5   unemploy  574 non-null    int64
#  6   year      574 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 31.5+ KB

# %%
fig, ax = plt.subplots(figsize=(8,5))

# usando seaborn 

sns.lineplot(x= "year" , y= "unemploy", data = economics, color="#56B4E9", legend=False)
plt.xlabel('Year')
plt.ylabel('Unemplyment')
# Out:
# Text(0, 0.5, 'Unemplyment')

# %% [markdown]
# ## Type of line
#
# - dash, dotted, dashdot, etc
#
#
# - markers
# markers = {'.': 'point', ',': 'pixel', 'o': 'circle', 'v': 'triangle_down', '^': 'triangle_up', '<': 'triangle_left', '>': 'triangle_right', '1': 'tri_down', '2': 'tri_up', '3': 'tri_left', '4': 'tri_right', '8': 'octagon', 's': 'square', 'p': 'pentagon', '*': 'star', 'h': 'hexagon1', 'H': 'hexagon2', '+': 'plus', 'x': 'x', 'D': 'diamond', 'd': 'thin_diamond', '|': 'vline', '_': 'hline', 'P': 'plus_filled', 'X': 'x_filled', 0: 'tickleft', 1: 'tickright', 2: 'tickup', 3: 'tickdown', 4: 'caretleft', 5: 'caretright', 6: 'caretup', 7: 'caretdown', 8: 'caretleftbase', 9: 'caretrightbase', 10: 'caretupbase', 11: 'caretdownbase', 'None': 'nothing', None: 'nothing', ' ': 'nothing', '': 'nothing'}¶

# %%
# Dash line

fig, ax = plt.subplots(figsize=(8,5))

sns.lineplot(x= "year" , y= "unemploy", data = economics, color="#56B4E9", legend=False, linestyle='--')

#: dotted, --: dashed

# forma de linea : linestyle

plt.xlabel('Year')
plt.ylabel('Unemplyment')
# Out:
# Text(0, 0.5, 'Unemplyment')

# %%
fig, ax = plt.subplots(figsize=(8,5))

sns.lineplot(x= "year" , y= "unemploy", data = economics, color="#56B4E9", legend=False, linestyle='dotted')
plt.xlabel('Year')
plt.ylabel('Unemplyment')
# Out:
# Text(0, 0.5, 'Unemplyment')

# %%
fig, ax = plt.subplots(figsize=(8,5))

sns.lineplot(x= "year" , y= "unemploy", data = economics, color="#56B4E9", legend=False, linestyle='dashdot')
plt.xlabel('Year')
plt.ylabel('Unemplyment')
# Out:
# Text(0, 0.5, 'Unemplyment')

# %%
fig, ax = plt.subplots(figsize=(8,5))

sns.lineplot(x= "year" , y= "uempmed", data = economics, color="#56B4E9", legend=False, linestyle='dashdot')
sns.lineplot(x= "year" , y= "psavert", data = economics, color="gray", legend=False, linewidth = 0.5)

ax.set_xmargin(0)  # drop espacios vacios right, left 
plt.ylim(0, 30)
plt.xlabel('Year')
plt.ylabel('saving rate / unemployment rate')
# Out:
# Text(0, 0.5, 'saving rate / unemployment rate')

# %%
# Visualizando la esperanza de vida media

paises = pd.read_csv(r"../../data/paises.csv" )
paises
# Out:
#             pais continente  anio  esperanza_de_vida  poblacion  \
# 0     Afganistán       Asia  1952             28.801    8425333
# 1     Afganistán       Asia  1957             30.332    9240934
# 2     Afganistán       Asia  1962             31.997   10267083
# 3     Afganistán       Asia  1967             34.020   11537966
# 4     Afganistán       Asia  1972             36.088   13079460
# ...          ...        ...   ...                ...        ...
# 1699    Zimbabue     África  1987             62.351    9216418
# 1700    Zimbabue     África  1992             60.377   10704340
# 1701    Zimbabue     África  1997             46.809   11404948
# 1702    Zimbabue     África  2002             39.989   11926563
# 1703    Zimbabue     África  2007             43.487   12311143
#
#       pib_per_capita
# 0         779.445314
# 1         820.853030
# 2         853.100710
# 3         836.197138
# 4         739.981106
# ...              ...
# 1699      706.157306
# ...

# %%
# group by

data_esp = paises.groupby('anio', as_index = False)['pib_per_capita'].mean()
data_esp
# Out:
#     anio  pib_per_capita
# 0   1952     3725.276046
# 1   1957     4299.408345
# 2   1962     4725.812342
# 3   1967     5483.653047
# 4   1972     6770.082815
# 5   1977     7313.166421
# 6   1982     7518.901673
# 7   1987     7900.920218
# 8   1992     8158.608521
# 9   1997     9090.175363
# 10  2002     9917.848365
# 11  2007    11680.071820

# %%
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params)  # theme de fondo blanco 

fig, ax = plt.subplots(figsize=(8,5))

sns.lineplot(x= "anio" , y= "pib_per_capita", data = data_esp, color="steelblue", legend=False, linewidth = 0.8)
sns.scatterplot(x= "anio" , y= "pib_per_capita", data = data_esp, color="black", legend=False, size = 0.8)

datos = data_esp.iloc[:,1]
fechas = data_esp.iloc[:,0]

# add text

for i, j in zip(datos, fechas):
    ax.text(j,i+600,round(i,1), color = 'black', size = 10, ha='center') # ax.text(x , y , dato, ...)

    
    # ax.text( x, y , dato, color, size ,... )
    
plt.ylim(2500,12500)  # ajustando rango del eje y
plt.xlim(1950,2010)

# labels en los ejes
plt.ylabel('PBI per-cápita media')
plt.xlabel('Año')

# ajsute de los valores en los ejes

ax.set_xticks(range(1952,2008,5))
ax.set_yticks(range(2500,12501,2000))

fig.savefig(r'../../output/plots/plot_time_pbi.png', dpi=800, bbox_inches='tight')

# %%
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params)

fig, ax = plt.subplots(figsize=(8,5))

sns.lineplot(x= "anio" , y= "pib_per_capita", data = data_esp, color="steelblue", marker = "o" ,legend=False, linewidth = 0.8)

datos = data_esp.iloc[:,1]
fechas = data_esp.iloc[:,0]

# add text

for i, j in zip(datos, fechas):
    ax.text(j,i+600,round(i,1), color = 'black', size = 10, ha='center') # ax.text(x , y , dato, ...)

plt.ylim(2500,12500)  # ajustando rango del eje y
plt.xlim(1950,2010)

# labels en los ejes
plt.ylabel('PBI per-cápita media')
plt.xlabel('Año')

# ajsute de los valores en los ejes

ax.set_xticks(range(1952,2008,5))
ax.set_yticks(range(2500,12501,2500))

# %%
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params)

fig, ax = plt.subplots(figsize=(8,5))

sns.lineplot(x= "anio" , y= "pib_per_capita", data = data_esp, color="steelblue", marker = "X" , markersize = 7,
             legend=False, linewidth = 0.8, linestyle='--')

datos = data_esp.iloc[:,1]
fechas = data_esp.iloc[:,0]

# add text

for i, j in zip(datos, fechas):
    ax.text(j,i+600,round(i,1), color = 'black', size = 10, ha='center') # ax.text(x , y , dato, ...)

plt.ylim(2500,12500)  # ajustando rango del eje y
plt.xlim(1950,2010)

# labels en los ejes
plt.ylabel('PBI per-cápita media')
plt.xlabel('Año')

# ajsute de los valores en los ejes

ax.set_xticks(range(1952,2008,5))
ax.set_yticks(range(2500,12501,2500))

# %% [markdown]
# ## <a id='4.0'> 4.0 Diagrama de dispersión (Binsplot)  </a>

# %%
rdata_read = pyreadr.read_r("../../data/wage2015_subsample_inference.Rdata")

# Extracting the data frame from rdata_read

data = rdata_read[ 'data' ]

# %%
z_clg = data[ data['clg'] == 1 ] # gente con universada (clg (college))

# %%
z_clg.size
# Out:
# 32720

# %%
# plot experiencia vs logaritmo del salario

sns.scatterplot(data=z_clg, x="exp1", y="lwage")
# Out:
# <AxesSubplot:xlabel='exp1', ylabel='lwage'>

# %%
# Line plot

fig = sns.lineplot(data=z_clg, x="exp1", y="lwage")
plt.xlabel('Years of experience')
plt.ylabel('Log of Wage')
plt.title('Wage and experience relationship \n for people who went to college')
# Out:
# Text(0.5, 1.0, 'Wage and experience relationship \n for people who went to college')

# %%
# Bins scatter plot

# We can also use the option bins from regplot to "split" data into bins
f, ax = plt.subplots(figsize=(10, 6))

ax = sns.regplot(x = z_clg.exp1, y=z_clg.lwage, color='red', x_bins=20, order=2, x_estimator=np.mean, fit_reg= True,
                 ci=False, line_kws={'lw':2.5,'color':"steelblue", 'linestyle':'dashdot'})

# bins: cantidad de grupos generados a aprtir de la muestra
# order: el grado de la regresión polpomica
# lw : linewidth (ancho de la linea)

plt.xlabel('Years of experience')
plt.ylabel('Log of Wage')
plt.title('Wage and experience relationship \n for people who went to college')

plt.legend(labels= ['Fitted wage - Quadratic','Actual wage bins-20'])

# la linea azul es el fitted (modelo estimado) de la sigueinte regresión
# Log(wage) ~ 1+ exp + -1.2exp^2 + u

# %%
# 1 , 2, 3, 4 ,5 , 6, 7, 8 

# 12, 15 , 20, 16 , 20 ,50, 10, 12

# %%
# 12, 15 , 20, 16 -> 18.5

# %%
# 20 ,50, 10, 12 -> 15.6

# %% [markdown]
# ## <a id='5.0'> References  </a>
#
# - Git Hub repository
#
# https://d2cml-ai.github.io/python_visual_library/python_notebooks/07_random_inference.html
#
# - Seaborn
#
# https://seaborn.pydata.org/examples/index.html
#
# - Type of markers
#
# https://matplotlib.org/2.1.2/api/_as_gen/matplotlib.pyplot.plot.html

# %%
from IPython.display import display, HTML

display(HTML(data="""
<style>
    div#notebook-container    { width: 75%; }
    div#menubar-container     { width: 80%; }
    div#maintoolbar-container { width: 80%; }a
</style>
"""))
# Out:
# <style>
#     div#notebook-container    { width: 75%; }
#     div#menubar-container     { width: 80%; }
#     div#maintoolbar-container { width: 80%; }a
# </style>

# %%
'''
Importar librerias
- numpy para operaciones de vectores y matrices
- pandas para manipular DataFrame (base de datos)
- Series para manipular columnas de DataFrame 
'''

import numpy as np
import pandas as pd
from pandas import DataFrame,Series

# %%
# importar el csv almacenada en la carpeta data
# relative path ../ salir de la carpeta Lab3
# /data ingresar a la carpeta data

netflix = pd.read_csv("../data/netflix_titles.csv") # pro default UTF-8 para caracteres especiales y lectura de missing 
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
netflix.info() # varaible's type 

print( netflix.shape ) # filas y columnas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB
# (7787, 12)

# %%
'''
Equivalent sum de Stata, solo la variable release_year es numerica
'''

netflix.describe()
# Out:
#        release_year
# count   7787.000000
# mean    2013.932580
# std        8.757395
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2018.000000
# max     2021.000000

# %%
## Verificando ID


print( netflix.show_id.unique() )

print( len( netflix.show_id.unique() ) )

print( netflix.show_id.is_unique )  # trueo false


##################################



# print( len(netflix['show_id'].unique() ) )

# netflix['show_id'].unique()

# netflix['show_id'].is_unique # verificando repeticiones
# Out:
# ['s1' 's2' 's3' ... 's7785' 's7786' 's7787']
# 7787
# True

# %%
netflix.release_year.is_unique
# Out:
# False

# %%
len( netflix.show_id.unique() )
# Out:
# 7787

# %%
netflix.show_id
# Out:
# 0          s1
# 1          s2
# 2          s3
# 3          s4
# 4          s5
#         ...
# 7782    s7783
# 7783    s7784
# 7784    s7785
# 7785    s7786
# 7786    s7787
# Name: show_id, Length: 7787, dtype: object

# %%
netflix[['director']]
# Out:
#                director
# 0                   NaN
# 1     Jorge Michel Grau
# 2          Gilbert Chan
# 3           Shane Acker
# 4        Robert Luketic
# ...                 ...
# 7782        Josef Fares
# 7783        Mozez Singh
# 7784                NaN
# 7785                NaN
# 7786           Sam Dunn
#
# [7787 rows x 1 columns]

# %% [markdown]
# ### ***Exploring a DataFrame***:

# %%
# Series en Python

print(type(netflix['director']))

netflix['director']
netflix.director
# Out:
# <class 'pandas.core.series.Series'>
# 0                     NaN
# 1       Jorge Michel Grau
# 2            Gilbert Chan
# 3             Shane Acker
# 4          Robert Luketic
#               ...
# 7782          Josef Fares
# 7783          Mozez Singh
# 7784                  NaN
# 7785                  NaN
# 7786             Sam Dunn
# Name: director, Length: 7787, dtype: object

# %%
## revisado missing values (NaN in Python)

print( netflix.director.unique() )
print( netflix.director.is_unique )

## isnull() and isna() son similares 

print( netflix.director.isnull() )

print( netflix['director'].isna() )
# Out:
# [nan 'Jorge Michel Grau' 'Gilbert Chan' ... 'Josef Fares' 'Mozez Singh'
#  'Sam Dunn']
# False
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7782    False
# 7783    False
# 7784     True
# 7785     True
# 7786    False
# Name: director, Length: 7787, dtype: bool
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7782    False
# 7783    False
# 7784     True
# 7785     True
# 7786    False
# Name: director, Length: 7787, dtype: bool

# %%
# cantidad de missing values en la variables director
print( netflix['director'].isna().sum() )

# Borrar missing values 

netflix.dropna() # borra todas las filas o columnas con al menos un missing value
netflix.dropna(axis = 0) # borras filas con missing value  , axis = 0 : aplicar función por filas
netflix.dropna(axis = 1) # borra columnas con al menos un missign values, axis = 1: aplicar función por columnas 

netflix.drop('listed_in', axis = 1) # elimiar columna listed_in

netflix.drop(7786) # eliminar una fila 

netflix.drop(columns = "listed_in", inplace = True)

# inplace = True permite alterar la base de datos sin la necesidad de asignarse nuevamente

#  netflix = netflix.drop(columns = "listed_in")
# Out:
# 2389

# %%
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix.dropna(subset = ['director'], inplace = True) # drop observaciones que presentan missing values en la columna director


 # Reemplazar missing values de la columna director con la palabra "Sin director"
# netflix.director = netflix.director.fillna("Sin director")

# %%
netflix
# Out:
#      show_id     type                                    title  \
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# 5         s6  TV Show                                       46
# ...      ...      ...                                      ...
# 7780   s7781    Movie                                      Zoo
# 7781   s7782    Movie                                     Zoom
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# ...

# %%
# netflix['director'] = netflix.director.fillna("Sin director")

# %%
# Alrerar la misma base de datos sin la necesidad de asignar a uno nuevo 

netflix.country.fillna("Sin nacionalidad", inplace = True)

# Qué funciones admiten Inplace = True

# drop, fillna, rename

# %%
netflix.isna().sum() # netflix.isna() hallar los missing por columna, .sum()  sumas la cantidad
# Out:
# show_id           0
# type              0
# title             0
# director          0
# cast            419
# country           0
# date_added        0
# release_year      0
# rating            4
# duration          0
# description       0
# dtype: int64

# %% [markdown]
# - Notese que la base de datos Netflix no ha sido alterada. Para que la base de datos se altere debe ocurrir dos cosas:
# 1. Asignarse a una nueva base de datos
# 2. Si la función lo permite, incluir el input ***Inplace = True***

# %%
# Create new variable
netflix['new_col'] = np.arange(0, netflix.shape[0]) # creat new varaible

# %%
netflix.shape[0]
# Out:
# 5398

# %%
netflix
# Out:
#      show_id     type                                    title  \
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# 5         s6  TV Show                                       46
# ...      ...      ...                                      ...
# 7780   s7781    Movie                                      Zoo
# 7781   s7782    Movie                                     Zoom
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# ...

# %%
# DataFrame.loc[ filas, columnas]

netflix.loc[210:500] # filtro por filas
# Out:
#     show_id   type                      title                    director  \
# 210    s211  Movie     A Night at the Roxbury            John Fortenberry
# 211    s212  Movie          A Noble Intention                Joram Lürsen
# 212    s213  Movie             A Patch of Fog              Michael Lennox
# 214    s215  Movie           A Perfect Ending                 Nicole Conn
# 215    s216  Movie              A Perfect Man            Kees Van Oostrum
# ..      ...    ...                        ...                         ...
# 496    s497  Movie            An Ordinary Man             Brad Silberling
# 497    s498  Movie  An Unremarkable Christmas          Juan Camilo Pinzon
# 498    s499  Movie          An Upper Egyptian  Ismail Farouk, Hazem Fouda
# 499    s500  Movie              Ana e Vitória               Matheus Souza
# 500    s501  Movie                   Anaamika              Sekhar Kammula
#
#                                                   cast                country  \
# ...

# %%
netflix.loc[210:] # desde fila indexing 210 hasta el final
# Out:
#      show_id   type                                    title  \
# 210     s211  Movie                   A Night at the Roxbury
# 211     s212  Movie                        A Noble Intention
# 212     s213  Movie                           A Patch of Fog
# 214     s215  Movie                         A Perfect Ending
# 215     s216  Movie                            A Perfect Man
# ...      ...    ...                                      ...
# 7780   s7781  Movie                                      Zoo
# 7781   s7782  Movie                                     Zoom
# 7782   s7783  Movie                                     Zozo
# 7783   s7784  Movie                                   Zubaan
# 7786   s7787  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#               director                                               cast  \
# 210   John Fortenberry  Will Ferrell, Chris Kattan, Dan Hedaya, Molly ...
# 211       Joram Lürsen  Gijs Scholten van Aschat, Jacob Derwig, Rifka ...
# ...

# %%
netflix.loc[:,['show_id','type','description']] # : todas las filas
# Out:
#      show_id     type                                        description
# 1         s2    Movie  After a devastating earthquake hits Mexico Cit...
# 2         s3    Movie  When an army recruit is found dead, his fellow...
# 3         s4    Movie  In a postapocalyptic world, rag-doll robots hi...
# 4         s5    Movie  A brilliant group of students become card-coun...
# 5         s6  TV Show  A genetics professor experiments with a treatm...
# ...      ...      ...                                                ...
# 7780   s7781    Movie  A drug dealer starts having doubts about his t...
# 7781   s7782    Movie  Dragged from civilian life, a former superhero...
# 7782   s7783    Movie  When Lebanon's Civil War deprives Zozo of his ...
# 7783   s7784    Movie  A scrappy but poor boy worms his way into a ty...
# 7786   s7787    Movie  This documentary delves into the mystique behi...
#
# [5398 rows x 3 columns]

# %%
'''
Loc usa los nombres de filas y columnas para filtrar
'''

# Filter rows

netflix.loc[0:100]
netflix.loc[210:500]
netflix.loc[210:] # desde la fila posición 210 hasta al final 

# filter columns 

netflix.loc[:,['show_id','type','description']]

netflix.loc[1000:2000,['show_id','type','description']]
# Out:
#      show_id   type                                        description
# 1001   s1002  Movie  Bad news from the past unhinges vagabond Dwigh...
# 1002   s1003  Movie  A jewel thief returns to his hiding place afte...
# 1003   s1004  Movie  As Cindy and Dean muddle through their languis...
# 1004   s1005  Movie  When his girlfriend learns the truth about his...
# 1005   s1006  Movie  Artists and industry insiders shed light on th...
# ...      ...    ...                                                ...
# 1992   s1993  Movie  In 1950s Makassar, the life of a devoted mothe...
# 1993   s1994  Movie  Expelled from private school for attempted sui...
# 1996   s1997  Movie  This documentary explores the extent to which ...
# 1997   s1998  Movie  Warehouse workers Vince and Zack compete in a ...
# 1999   s2000  Movie  After accidentally killing a young mobster, a ...
#
# [663 rows x 3 columns]

# %%
netflix[['show_id','type','description']]
# Out:
#      show_id     type                                        description
# 1         s2    Movie  After a devastating earthquake hits Mexico Cit...
# 2         s3    Movie  When an army recruit is found dead, his fellow...
# 3         s4    Movie  In a postapocalyptic world, rag-doll robots hi...
# 4         s5    Movie  A brilliant group of students become card-coun...
# 5         s6  TV Show  A genetics professor experiments with a treatm...
# ...      ...      ...                                                ...
# 7780   s7781    Movie  A drug dealer starts having doubts about his t...
# 7781   s7782    Movie  Dragged from civilian life, a former superhero...
# 7782   s7783    Movie  When Lebanon's Civil War deprives Zozo of his ...
# 7783   s7784    Movie  A scrappy but poor boy worms his way into a ty...
# 7786   s7787    Movie  This documentary delves into the mystique behi...
#
# [5398 rows x 3 columns]

# %%
netflix
# Out:
#      show_id     type                                    title  \
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# 5         s6  TV Show                                       46
# ...      ...      ...                                      ...
# 7780   s7781    Movie                                      Zoo
# 7781   s7782    Movie                                     Zoom
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# ...

# %%
#netflix.set_index( [ 'show_id' ] , inplace = True)
netflix
# Out:
#             type                                    title           director  \
# show_id
# s2         Movie                                     7:19  Jorge Michel Grau
# s3         Movie                                    23:59       Gilbert Chan
# s4         Movie                                        9        Shane Acker
# s5         Movie                                       21     Robert Luketic
# s6       TV Show                                       46        Serdar Akar
# ...          ...                                      ...                ...
# s7781      Movie                                      Zoo       Shlok Sharma
# s7782      Movie                                     Zoom       Peter Hewitt
# s7783      Movie                                     Zozo        Josef Fares
# s7784      Movie                                   Zubaan        Mozez Singh
# s7787      Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS           Sam Dunn
#
# ...

# %%
# Filtrando columnas por index

netflix.loc[ ['s2','s100','s7787'] ]
# Out:
#           type                                    title           director  \
# show_id
# s2       Movie                                     7:19  Jorge Michel Grau
# s100     Movie                               3 Heroines     Iman Brotoseno
# s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS           Sam Dunn
#
#                                                       cast  \
# show_id
# s2       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# s100     Reza Rahadian, Bunga Citra Lestari, Tara Basro...
# s7787                                                  NaN
#
#                                        country         date_added  \
# show_id
# s2                                      Mexico  December 23, 2016
# s100                                 Indonesia    January 5, 2019
# s7787    United Kingdom, Canada, United States      March 1, 2020
#
#          release_year rating duration  \
# show_id
# s2               2016  TV-MA   93 min
# ...

# %%
# Reset index 

netflix.reset_index( inplace = True) #

# %%
netflix
# Out:
#      show_id     type                                    title  \
# 0         s2    Movie                                     7:19
# 1         s3    Movie                                    23:59
# 2         s4    Movie                                        9
# 3         s5    Movie                                       21
# 4         s6  TV Show                                       46
# ...      ...      ...                                      ...
# 5393   s7781    Movie                                      Zoo
# 5394   s7782    Movie                                     Zoom
# 5395   s7783    Movie                                     Zozo
# 5396   s7784    Movie                                   Zubaan
# 5397   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# ...

# %%
'''
iloc usa las posiciones de filas y columnas
'''

# Filter rows

netflix.iloc[0:100]
# Out:
#    show_id     type       title           director  \
# 0       s2    Movie        7:19  Jorge Michel Grau
# 1       s3    Movie       23:59       Gilbert Chan
# 2       s4    Movie           9        Shane Acker
# 3       s5    Movie          21     Robert Luketic
# 4       s6  TV Show          46        Serdar Akar
# ..     ...      ...         ...                ...
# 95    s123    Movie       50/50    Jonathan Levine
# 96    s124    Movie         5CM    Rizal Mantovani
# 97    s125    Movie       5Gang         Matei Dima
# 98    s126    Movie  6 Balloons   Marja Lewis Ryan
# 99    s127    Movie      6 Days         Toa Fraser
#
#                                                  cast  \
# 0   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 1   Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 2   Elijah Wood, John C. Reilly, Jennifer Connelly...
# 3   Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 4   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# ...

# %%
netflix.iloc[210:500]
# Out:
#     show_id   type                                      title  \
# 210    s266  Movie                             Aagey Se Right
# 211    s267  Movie                         Aajcha Divas Majha
# 212    s268  Movie                             Aakhri Adaalat
# 213    s269  Movie                                 Aalorukkam
# 214    s270  Movie                                      Aamir
# ..      ...    ...                                        ...
# 495    s649  Movie  Aziz Ansari Live at Madison Square Garden
# 496    s650  Movie                  Aziz Ansari: Buried Alive
# 497    s651  Movie                     Aziz Ansari: RIGHT NOW
# 498    s653  Movie                                  B.A. Pass
# 499    s654  Movie                                B.A. Pass 2
#
#                           director  \
# 210               Indrajit Nattoji
# 211           Chandrakant Kulkarni
# 212                    Rajiv Mehra
# 213                   V C Abhilash
# 214                Raj Kumar Gupta
# ...

# %%
# filter columns 

netflix.iloc[:,[0,1,10]] # filtrando por posiciones de columnas
# Out:
#      show_id     type                                        description
# 0         s2    Movie  After a devastating earthquake hits Mexico Cit...
# 1         s3    Movie  When an army recruit is found dead, his fellow...
# 2         s4    Movie  In a postapocalyptic world, rag-doll robots hi...
# 3         s5    Movie  A brilliant group of students become card-coun...
# 4         s6  TV Show  A genetics professor experiments with a treatm...
# ...      ...      ...                                                ...
# 5393   s7781    Movie  A drug dealer starts having doubts about his t...
# 5394   s7782    Movie  Dragged from civilian life, a former superhero...
# 5395   s7783    Movie  When Lebanon's Civil War deprives Zozo of his ...
# 5396   s7784    Movie  A scrappy but poor boy worms his way into a ty...
# 5397   s7787    Movie  This documentary delves into the mystique behi...
#
# [5398 rows x 3 columns]

# %%
netflix.iloc[1000:2000,[0,1,10]]
# Out:
#      show_id   type                                        description
# 1000   s1376  Movie  Soccer goalie Claudio Tamburrini is kidnapped ...
# 1001   s1384  Movie  Mistaking a broke, small-time hustler for a mi...
# 1002   s1385  Movie  The lives of five hapless, petty criminals car...
# 1003   s1386  Movie  Jealous of the high regard in which his new wi...
# 1004   s1388  Movie  A young man in Kerala has two weeks to stop th...
# ...      ...    ...                                                ...
# 1995   s2856  Movie  Hubie's not the most popular guy in Salem, Mas...
# 1996   s2858  Movie  Living inside a Paris train station, an orphan...
# 1997   s2859  Movie  This action-packed animated double feature pit...
# 1998   s2860  Movie  Although Nisha falls for Prem, she agrees to m...
# 1999   s2861  Movie  A scheming matriarch plots to cut off her disa...
#
# [1000 rows x 3 columns]

# %%
# Column names in a list
list(netflix.columns)
# Out:
# ['show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'release_year',
#  'rating',
#  'duration',
#  'description']

# %% [markdown]
# ### ***Sorting and Subsetting***

# %%
# sort ascendet 
netflix.sort_values("release_year", inplace = True)
netflix
# Out:
#      show_id     type                                              title  \
# 4259   s6118    Movie                               The Battle of Midway
# 3451   s4961    Movie                                     Prelude to War
# 5100   s7343    Movie      Undercover: How to Operate Behind Enemy Lines
# 5286   s7617    Movie                 Why We Fight: The Battle of Russia
# 5325   s7680    Movie                    WWII: Report from the Aleutians
# ...      ...      ...                                                ...
# 5026   s7221    Movie                      Tribhanga - Tedhi Medhi Crazy
# 981    s1356    Movie  Chris Rock Total Blackout: The Tamborine Exten...
# 5306   s7645    Movie                                           Wish You
# 940    s1286    Movie                                           Charming
# 4508   s6478  TV Show                               The Idhun Chronicles
#
#                          director  \
# 4259                    John Ford
# ...

# %%
netflix.sort_values("release_year", ascending = False, inplace = True)
netflix.head(10)
# Out:
#      show_id     type                                              title  \
# 4508   s6478  TV Show                               The Idhun Chronicles
# 3122   s4469  TV Show        Night Stalker: The Hunt for a Serial Killer
# 940    s1286    Movie                                           Charming
# 5306   s7645    Movie                                           Wish You
# 981    s1356    Movie  Chris Rock Total Blackout: The Tamborine Exten...
# 5026   s7221    Movie                      Tribhanga - Tedhi Medhi Crazy
# 5241   s7552    Movie                          What Happened to Mr. Cha?
# 5253   s7570    Movie                        What Would Sophia Loren Do?
# 3293   s4711    Movie                                   Outside the Wire
# 3551   s5104    Movie  Ratones Paranoicos: The Band that Rocked Argen...
#
#                              director  \
# 4508             Maite Ruiz De Austri
# 3122                   Tiller Russell
# 940                      Ross Venokur
# ...

# %%
netflix['number'] = np.random.randint(1, 10, netflix.shape[0])

# %%
netflix.sort_values(["release_year","number"], inplace = True)
netflix.head(10)
# Out:
#      show_id     type                                              title  \
# 4867   s4868  TV Show                  Pioneers: First Women Filmmakers*
# 4960   s4961    Movie                                     Prelude to War
# 6117   s6118    Movie                               The Battle of Midway
# 7616   s7617    Movie                 Why We Fight: The Battle of Russia
# 7342   s7343    Movie      Undercover: How to Operate Behind Enemy Lines
# 7679   s7680    Movie                    WWII: Report from the Aleutians
# 6657   s6658    Movie  The Memphis Belle: A Story of a\r\nFlying Fort...
# 6699   s6700    Movie                                  The Negro Soldier
# 7268   s7269    Movie                                   Tunisian Victory
# 3425   s3426    Movie                            Know Your Enemy - Japan
#
#                                                director  \
# 4867                                       Sin director
# ...

# %%
net_two_sort = netflix.sort_values(["release_year","number"], ascending = [True,False]) 
net_two_sort.head(10)
# obs : en 1943 ==> en ["duration"] lo ordena de forma descendente
# Out:
#      show_id   type                                              title  \
# 3451   s4961  Movie                                     Prelude to War
# 4259   s6118  Movie                               The Battle of Midway
# 5325   s7680  Movie                    WWII: Report from the Aleutians
# 5286   s7617  Movie                 Why We Fight: The Battle of Russia
# 5100   s7343  Movie      Undercover: How to Operate Behind Enemy Lines
# 5053   s7269  Movie                                   Tunisian Victory
# 4659   s6700  Movie                                  The Negro Soldier
# 4635   s6658  Movie  The Memphis Belle: A Story of a\r\nFlying Fort...
# 3101   s4437  Movie                           Nazi Concentration Camps
# 3746   s5372  Movie                                         San Pietro
#
#                                                director  \
# 3451                                        Frank Capra
# 4259                                          John Ford
# ...

# %% [markdown]
# ### ***Subsetting columns***

# %%
netflix.director
# Out:
# 0            Sin director
# 1       Jorge Michel Grau
# 2            Gilbert Chan
# 3             Shane Acker
# 4          Robert Luketic
#               ...
# 7782          Josef Fares
# 7783          Mozez Singh
# 7784         Sin director
# 7785         Sin director
# 7786             Sam Dunn
# Name: director, Length: 7787, dtype: object

# %%
netflix[["director","cast"]]
# Out:
#                director                                               cast
# 0          Sin director  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3           Shane Acker  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4        Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...                 ...                                                ...
# 7782        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783        Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784       Sin director                                            Nasty C
# 7785       Sin director                         Adriano Zumbo, Rachel Khoo
# 7786           Sam Dunn                                                NaN
#
# [7787 rows x 2 columns]

# %% [markdown]
# ### ***Subsetting rows***

# %%
netflix[ netflix["release_year"] < 2011 ]
# Out:
#      show_id   type                                          title  \
# 4291   s6163  Movie                              The Bounty Hunter
# 4795   s6885  Movie                             The Social Network
# 3591   s5167  Movie                       Resident Evil: Afterlife
# 5278   s7605  Movie                   Whitney Cummings: Money Shot
# 475     s623  Movie                                         Aurora
# ...      ...    ...                                            ...
# 5325   s7680  Movie                WWII: Report from the Aleutians
# 5100   s7343  Movie  Undercover: How to Operate Behind Enemy Lines
# 5286   s7617  Movie             Why We Fight: The Battle of Russia
# 3451   s4961  Movie                                 Prelude to War
# 4259   s6118  Movie                           The Battle of Midway
#
#                          director  \
# 4291                 Andy Tennant
# 4795                David Fincher
# 3591           Paul W.S. Anderson
# ...

# %%
netflix[(netflix["release_year"] < 2011) & (netflix["number"] > 5)]  # para más de un condicional colocar los casos en paréntesis
# Out:
#      show_id   type                            title  \
# 4291   s6163  Movie                The Bounty Hunter
# 3591   s5167  Movie         Resident Evil: Afterlife
# 475     s623  Movie                           Aurora
# 3507   s5048  Movie                        Raajneeti
# 3696   s5309  Movie   Rush: Beyond the Lighted Stage
# ...      ...    ...                              ...
# 3563   s5123  Movie            Rebel Without a Cause
# 3790   s5426  Movie              Scandal in Sorrento
# 4929   s7073  Movie                      Thunderbolt
# 5053   s7269  Movie                 Tunisian Victory
# 5325   s7680  Movie  WWII: Report from the Aleutians
#
#                                                director  \
# 4291                                       Andy Tennant
# 3591                                 Paul W.S. Anderson
# 475                                         Cristi Puiu
# 3507                                        Prakash Jha
# ...

# %%
netflix[( netflix.release_year < 2011 ) & (netflix.number > 5)]
# Out:
#      show_id   type                            title             director  \
# 4960   s4961  Movie                   Prelude to War          Frank Capra
# 6117   s6118  Movie             The Battle of Midway            John Ford
# 7679   s7680  Movie  WWII: Report from the Aleutians          John Huston
# 5371   s5372  Movie                       San Pietro          John Huston
# 4436   s4437  Movie         Nazi Concentration Camps       George Stevens
# ...      ...    ...                              ...                  ...
# 915     s916  Movie             Bill Burr: Let It Go      Shannon Hartman
# 299     s300  Movie                 Act of Vengeance    Mahsun Kırmızıgül
# 6596   s6597  Movie             The Light of My Eyes         Sin director
# 4302   s4303  Movie                  My Amnesia Girl  Cathy Garcia-Molina
# 7061   s7062  Movie               Thorne: Sleepyhead      Stephen Hopkins
#
#                                                    cast  \
# ...

# %%
netflix[['director']].iloc[0:10]
# Out:
#                                                director
# 4867                                       Sin director
# 4960                                        Frank Capra
# 6117                                          John Ford
# 7616                        Frank Capra, Anatole Litvak
# 7342                                          John Ford
# 7679                                        John Huston
# 6657                                      William Wyler
# 6699                                     Stuart Heisler
# 7268  Frank Capra, John Huston, Hugh Stewart, Roy Bo...
# 3425                           Frank Capra, Joris Ivens

# %%
netflix
# Out:
#      show_id     type                                          title  \
# 4867   s4868  TV Show              Pioneers: First Women Filmmakers*
# 4960   s4961    Movie                                 Prelude to War
# 6117   s6118    Movie                           The Battle of Midway
# 7616   s7617    Movie             Why We Fight: The Battle of Russia
# 7342   s7343    Movie  Undercover: How to Operate Behind Enemy Lines
# ...      ...      ...                                            ...
# 1864   s1865  TV Show                            Dream Home Makeover
# 4468   s4469  TV Show    Night Stalker: The Hunt for a Serial Killer
# 1528   s1529    Movie                    Creating The Queen's Gambit
# 4965   s4966  TV Show                            Pretend It’s a City
# 7551   s7552    Movie                      What Happened to Mr. Cha?
#
#                          director                                      cast  \
# ...

# %% [markdown]
# ### ***Subsetting based on text data***

# %%
net_peru = netflix[netflix.country == "Peru"]
net_peru
# Out:
#      show_id   type                           title  \
# 1988   s2846  Movie       How to Get Over a Breakup
# 3937   s5635  Movie                 Sinister Circle
# 3306   s4733  Movie  Pacificum: Return to the Ocean
# 463     s605  Movie                      Asu Mare 2
#
#                             director  \
# 1988  Joanna Lombardi, Bruno Ascenzo
# 3937          Dorian Fernández-Moris
# 3306  Mariana Tschudi, Héctor Gálvez
# 463                Ricardo Maldonado
#
#                                                    cast country  \
# 1988  Gisela Ponce de León, Karina Jordán, Jely Reát...    Peru
# 3937  Milene Vázquez, Matías Raygada, Claudia Dammer...    Peru
# 3306                                                NaN    Peru
# 463   Carlos Alcántara, Emilia Drago, Christian Meie...    Peru
#
#             date_added  release_year rating duration  \
# 1988  October 20, 2018          2018  TV-MA  104 min
# 3937   October 1, 2019          2017  TV-MA   87 min
# ...

# %%
net_mex = netflix[netflix["country"] == "Mexico"]
net_mex
# Out:
#      show_id   type                                    title  \
# 1118   s1577  Movie                               Dad Wanted
# 1141   s1615  Movie                              Dark Forces
# 4824   s6928  Movie    The Three Deaths of Marisela Escobedo
# 3010   s4300  Movie                Mutiny of the Worker Bees
# 3634   s5230  Movie                             ROAD TO ROMA
# ...      ...    ...                                      ...
# 4670   s6721  Movie  The Old Thieves: The Legend of Artegios
# 5335   s7691  Movie                        Y Tu Mamá También
# 3862   s5527  Movie                   Sexo, Pudor y Lagrimas
# 2556   s3640  Movie                 Like Water for Chocolate
# 3982   s5698  Movie                       Solo Con Tu Pareja
#
#                  director                                               cast  \
# 1118       Javier Colinas  Natalia Coronado, Juan Pablo Medina, Silvia Na...
# ...

# %% [markdown]
# # ***Filtering Data***

# %% [markdown]
# ### Checking unique values

# %%
netflix["country"].unique()
# Out:
# array([nan, 'United States', 'United States, United Kingdom', 'Egypt',
#        'Italy, France', 'Italy', 'India', 'India, Malaysia',
#        'United Kingdom, United States',
#        'United States, Italy, United Kingdom, Liechtenstein', 'Poland',
#        'Italy, United States',
#        'United States, East Germany, West Germany',
#        'United Kingdom, West Germany', 'Hong Kong, United States',
#        'Hong Kong', 'United Kingdom', 'France', 'Lebanon', 'Poland,',
#        'West Germany', 'Egypt, Algeria', 'Japan', 'Mexico',
#        'Lebanon, Canada, France', 'Australia, United States',
#        'Soviet Union, India', 'Kuwait', 'Australia', 'France, Lebanon',
#        'India, Soviet Union', 'Poland, West Germany', 'Argentina',
#        'United States, Japan',
#        'Italy, South Africa, West Germany, Australia, United States',
#        'Hong Kong, China', 'Denmark, France, Poland',
#        'United States, Canada', 'Ireland, United Kingdom, United States',
# ...

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      7787 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
#  12  new_col       7787 non-null   int32
#  13  number        7787 non-null   int32
# dtypes: int32(2), int64(1), object(11)
# memory usage: 791.0+ KB

# %%
netflix.head(3)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%       Sin director
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 cast    country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          description  new_col  number
# ...

# %% [markdown]
# ### Example

# %%
netflix[netflix.type == "TV Show"]
# Out:
#      show_id     type                                             title  \
# 4508   s6478  TV Show                              The Idhun Chronicles
# 3122   s4469  TV Show       Night Stalker: The Hunt for a Serial Killer
# 1629   s2321  TV Show                                      Futmalls.com
# 1651   s2348  TV Show                         Gameboys Level-Up Edition
# 4748   s6825  TV Show                                        The Ripper
# ...      ...      ...                                               ...
# 3286   s4701  TV Show                       Ouran High School Host Club
# 155     s196  TV Show                               A Lion in the House
# 4282   s6149  TV Show  The Blue Planet: A Natural History of the Oceans
# 2353   s3335  TV Show                          Ken Burns: The Civil War
# 3410   s4867  TV Show               Pioneers of African-American Cinema
#
#                                                director  \
# ...

# %%
len( netflix.loc[netflix["type"] == "TV Show"] )
# Out:
# 2410

# %%
netflix[(netflix["type"] == "TV Show") & (netflix["country"] == "Peru")]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, new_col, number]
# Index: []

# %%
# No hay series peruanas en Netflix

len(netflix[(netflix["country"] == "Brazil") | (netflix["country"] == "Peru")])
# Out:
# 76

# %%
netflix[(netflix["type"] == "TV Show") | (netflix["country"] == "Peru")]
# Out:
#      show_id     type                                             title  \
# 4508   s6478  TV Show                              The Idhun Chronicles
# 3122   s4469  TV Show       Night Stalker: The Hunt for a Serial Killer
# 1629   s2321  TV Show                                      Futmalls.com
# 1651   s2348  TV Show                         Gameboys Level-Up Edition
# 4748   s6825  TV Show                                        The Ripper
# ...      ...      ...                                               ...
# 3286   s4701  TV Show                       Ouran High School Host Club
# 155     s196  TV Show                               A Lion in the House
# 4282   s6149  TV Show  The Blue Planet: A Natural History of the Oceans
# 2353   s3335  TV Show                          Ken Burns: The Civil War
# 3410   s4867  TV Show               Pioneers of African-American Cinema
#
#                                                director  \
# ...

# %%
# peliculas americanas
netflix.loc[(netflix["type"] == "Movie") & (netflix["country"] == "United States") 
            & (netflix["release_year"] > 2019)].head(5)
# Out:
#      show_id   type                                    title  \
# 5253   s7570  Movie              What Would Sophia Loren Do?
# 1080   s1515  Movie  Crack: Cocaine, Corruption & Conspiracy
# 4663   s6709  Movie                          The Night Clerk
# 1620   s2311  Movie                Full Out 2: You Got This!
# 4669   s6720  Movie                            The Old Guard
#
#                    director  \
# 5253          Ross Kauffman
# 1080         Stanley Nelson
# 4663      Michael Cristofer
# 1620          Jeff Deverett
# 4669  Gina Prince-Bythewood
#
#                                                    cast        country  \
# 5253        Nancy "Vincenza Careri" Kulik, Sophia Loren  United States
# 1080                                                NaN  United States
# 4663  Tye Sheridan, Ana de Armas, Helen Hunt, John L...  United States
# 1620  Sydney Cope, Logan Edra, Liza Wilk, Braedyn Br...  United States
# ...

# %%
# Brazil in 2020
net_B_2020 = netflix[(netflix["country"] == "Brazil") & (netflix["release_year"] == 2020)]
net_B_2020.head(3)
# Out:
#     show_id     type                      title                      director  \
# 0        s1  TV Show                         3%                           NaN
# 218    s219  TV Show            A Queen Is Born                  Carla Barros
# 320    s321    Movie  Afonso Padilha: Classless  Junior Carelli, Rudge Campos
#
#                                                   cast country  \
# 0    João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 218                      Gloria Groove, Alexia Twister  Brazil
# 320                                     Afonso Padilha  Brazil
#
#             date_added  release_year rating   duration  \
# 0      August 14, 2020          2020  TV-MA  4 Seasons
# 218  November 11, 2020          2020  TV-14   1 Season
# 320  September 3, 2020          2020  TV-MA     63 min
#
#                                              listed_in  \
# 0    International TV Shows, TV Dramas, TV Sci-Fi &...
# 218                 International TV Shows, Reality TV
# ...

# %% [markdown]
# # .isin()
# If you want to filter by multiple values of a categorical variable, the easiest way is to use the isin() method.

# %%
# Peliculas de Perú y Chile

net_per_ch = netflix[netflix["country"].isin(["Peru","Chile"])] # filter by variables's values
net_per_ch
# Out:
#      show_id   type                                        title  \
# 3143   s4500  Movie                        Nobody Knows I'm Here
# 2989   s4273  Movie                               Mujeres arriba
# 2840   s4062  Movie                              Mi amigo Alexis
# 3087   s4416  Movie             Natalia Valdebenito: El especial
# 3135   s4487  Movie                                No Estoy Loca
# 2186   s3124  Movie  Jani Dueñas: Grandes fracasos de ayer y hoy
# 1988   s2846  Movie                    How to Get Over a Breakup
# 1465   s2087  Movie           Fabrizio Copano: Solo pienso en mi
# 3937   s5635  Movie                              Sinister Circle
# 3306   s4733  Movie               Pacificum: Return to the Ocean
# 2695   s3851  Movie                                        Madre
# 473     s619  Movie                                Attitude Test
# 463     s605  Movie                                   Asu Mare 2
# ...

# %%
# Peliculas diferentes de Perú y Chile

netflix[~ netflix["country"].isin(["Peru","Chile"])]   # ~ negación en Python ALT + 126
# Out:
#      show_id     type                                              title  \
# 4508   s6478  TV Show                               The Idhun Chronicles
# 3122   s4469  TV Show        Night Stalker: The Hunt for a Serial Killer
# 940    s1286    Movie                                           Charming
# 5306   s7645    Movie                                           Wish You
# 981    s1356    Movie  Chris Rock Total Blackout: The Tamborine Exten...
# ...      ...      ...                                                ...
# 5325   s7680    Movie                    WWII: Report from the Aleutians
# 5100   s7343    Movie      Undercover: How to Operate Behind Enemy Lines
# 5286   s7617    Movie                 Why We Fight: The Battle of Russia
# 3451   s4961    Movie                                     Prelude to War
# 4259   s6118    Movie                               The Battle of Midway
#
#                          director  \
# 4508         Maite Ruiz De Austri
# ...

# %% [markdown]
# ## Alternative methods to filter

# %%
movie = netflix["type"] == "Movie"
m_usa = netflix["country"] == "United States"
m_actual = netflix["release_year"] > 2019

movie_usa = netflix[movie & m_usa & m_actual]
movie_usa
# Out:
#      show_id   type                                    title  \
# 5253   s7570  Movie              What Would Sophia Loren Do?
# 1080   s1515  Movie  Crack: Cocaine, Corruption & Conspiracy
# 4663   s6709  Movie                          The Night Clerk
# 1620   s2311  Movie                Full Out 2: You Got This!
# 4669   s6720  Movie                            The Old Guard
# ...      ...    ...                                      ...
# 363     s471  Movie    American Murder: The Family Next Door
# 482     s632  Movie                                      Ava
# 559     s742  Movie                Barbie Princess Adventure
# 112     s148  Movie  A Babysitter's Guide to Monster Hunting
# 5129   s7390  Movie                   Vampires vs. the Bronx
#
#                    director  \
# 5253          Ross Kauffman
# 1080         Stanley Nelson
# 4663      Michael Cristofer
# 1620          Jeff Deverett
# 4669  Gina Prince-Bythewood
# ...                     ...
# ...

# %%
movie_usa = netflix.loc[ ( netflix[ "type" ] == "Movie" ) & ( netflix[ "country" ] == "United States") & ( netflix[ "release_year" ] > 2019 ) ]

# %%
movie_usa
# Out:
#      show_id   type                                    title  \
# 154     s155  Movie                   A California Christmas
# 611     s612  Movie                                Athlete A
# 1135   s1136  Movie                            Bulletproof 2
# 1569   s1570  Movie                              Da 5 Bloods
# 7370   s7371  Movie         Uppity: The Willy T. Ribbs Story
# ...      ...    ...                                      ...
# 2434   s2435  Movie                             Giving Voice
# 3830   s3831  Movie                 Ma Rainey's Black Bottom
# 6670   s6671  Movie             The Minimalists: Less Is Now
# 7569   s7570  Movie              What Would Sophia Loren Do?
# 1514   s1515  Movie  Crack: Cocaine, Corruption & Conspiracy
#
#                               director  \
# 154               Shaun Paul Piccinino
# 611             Bonni Cohen, Jon Shenk
# 1135                  Don Michael Paul
# 1569                         Spike Lee
# ...

# %%
movie_usa.drop(['show_id', 'director'], axis=1, inplace = True ) # axis = 1 , drop por columna
# Out:
# C:\Users\Roberto\AppData\Local\Temp\ipykernel_18864\3584590493.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_usa.drop(['show_id', 'director'], axis=1, inplace = True ) # axis = 1 , drop por columna

# %%
movie_usa
# Out:
#        type                                    title  \
# 5253  Movie              What Would Sophia Loren Do?
# 1080  Movie  Crack: Cocaine, Corruption & Conspiracy
# 4663  Movie                          The Night Clerk
# 1620  Movie                Full Out 2: You Got This!
# 4669  Movie                            The Old Guard
# ...     ...                                      ...
# 363   Movie    American Murder: The Family Next Door
# 482   Movie                                      Ava
# 559   Movie                Barbie Princess Adventure
# 112   Movie  A Babysitter's Guide to Monster Hunting
# 5129  Movie                   Vampires vs. the Bronx
#
#                                                    cast        country  \
# 5253        Nancy "Vincenza Careri" Kulik, Sophia Loren  United States
# 1080                                                NaN  United States
# 4663  Tye Sheridan, Ana de Armas, Helen Hunt, John L...  United States
# ...

# %% [markdown]
# # Axis:
#
# - drop, concat: axis = 0  filas, axis = 1 columnas
#
# - En funciones aplciado a columnas (mean, std, apply:lambda) DataFrame o matrices Axis = 1 (filas), mientras axos = 0 (columnas)

# %%
movie_usa[movie_usa.release_year != 2020]
# Out:
#        type                                    title  \
# 6670  Movie             The Minimalists: Less Is Now
# 7569  Movie              What Would Sophia Loren Do?
# 1514  Movie  Crack: Cocaine, Corruption & Conspiracy
#
#                                              cast        country  \
# 6670                                          NaN  United States
# 7569  Nancy "Vincenza Careri" Kulik, Sophia Loren  United States
# 1514                                          NaN  United States
#
#             date_added  release_year rating duration      listed_in  \
# 6670   January 1, 2021          2021  TV-14   54 min  Documentaries
# 7569  January 15, 2021          2021  TV-14   32 min  Documentaries
# 1514  January 11, 2021          2021  TV-MA   90 min  Documentaries
#
#                                             description  new_col  number
# 6670  They've built a movement out of minimalism. Lo...     6670       1
# ...

# %%
#Rename variables

movie_usa.rename(columns = {'title':'Titulo_movie', 'duration':'Duration_movie'}, inplace = True)
# Out:
# C:\Users\Roberto\AppData\Local\Temp\ipykernel_18864\1458485735.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_usa.rename(columns = {'title':'Titulo_movie', 'duration':'Duration_movie'}, inplace = True)

# %%
movie_usa
# Out:
#        type                             Titulo_movie  \
# 5253  Movie              What Would Sophia Loren Do?
# 1080  Movie  Crack: Cocaine, Corruption & Conspiracy
# 4663  Movie                          The Night Clerk
# 1620  Movie                Full Out 2: You Got This!
# 4669  Movie                            The Old Guard
# ...     ...                                      ...
# 363   Movie    American Murder: The Family Next Door
# 482   Movie                                      Ava
# 559   Movie                Barbie Princess Adventure
# 112   Movie  A Babysitter's Guide to Monster Hunting
# 5129  Movie                   Vampires vs. the Bronx
#
#                                                    cast        country  \
# 5253        Nancy "Vincenza Careri" Kulik, Sophia Loren  United States
# 1080                                                NaN  United States
# 4663  Tye Sheridan, Ana de Armas, Helen Hunt, John L...  United States
# ...

# %% [markdown]
# ### Export data

# %%
movie_usa.to_csv("../data/movie_usa_1.csv")

# %%
movie_usa.to_excel("../data/movie_usa_1.xlsx")

# %% [markdown]
# ### References
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html
